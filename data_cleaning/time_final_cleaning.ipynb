# %% [markdown]
# # initial subdivison in time classes

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
time_df = pd.read_excel("../_results/text_temp_cleaned_handmatig_finalversion.xlsx", index_col=0)

# %%
time_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 512        50       15      NaN       109        11       NaN      NaN
# 1299       50       18      NaN       108        56       NaN      NaN
# 1536       50       24      NaN       110        44       NaN      NaN
# 1760       50       46      NaN       111        25       NaN      NaN
# 1890       50       10      NaN       108        54       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 1150       50       27      NaN       108        38       NaN      NaN
# 1396       55       51      NaN       118        58       NaN      NaN
# 2116       52       29      NaN       117        32      50.0      NaN
# 2973       63       45      NaN       143        30       NaN      NaN
# 4077       70        3      NaN       140         7       NaN      NaN
#
#                    type_granite   time                       massif  \
# ...

# %%
time_df.loc[:, 'time']
time_df.iloc[:, 8].value_counts().to_excel("../_RESULTS/time_counts_initial.xlsx")

# %%
classification_renaming_dict = {"J 1_2" : "J1-J2",
                                "K1-K2" : "K",
                                "Mz1" : "Mz",
                                "Mz3" : "Mz",
                                "K2-Pg1" : "K2-Pg",
                                "K2_Pg" : "K2-Pg",
                                "Pg3" : "Pg",
                                "Pg2" : "Pg",
                                "Pg1_2" : "Pg",
                                "J-Pg3" : "J-K",
                                "Pg2_3" : "Pg",
                                "J3-Pg1" : "J-K",
                                "J-Pg" : "J-K",
                                "Tr1-J1" : "Tr-J",                             
                                "J2-K" : "J-K",
                                "J3-K1" : "J-K",
                                "J3-Pg" : "J-K",
                                "Tr3-J" : "Tr-J",
                                "Tr-J2" : "Tr-J",
                                "Tr1" : "Tr",
                                "Tr2_3" : "Tr",
                                "Tr2" : "Tr",
                                "Tr3" : "Tr",
                                "K1_2" : "K",
                                "Pg1" : "Pg",
                                "Tr3-J1" : "Tr-J",
                                "Tr-J1" : "Tr-J",
                                "J2_3" : "J2-J3",
                                "J1_2" : "J1-J2"}

# %%
time_df['time'] = time_df['time'].replace(classification_renaming_dict)

# %%
time_df.iloc[:, 8].value_counts().to_excel("../_RESULTS/time_counts_initial.xlsx")

# %%
time_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 512        50       15      NaN       109        11       NaN      NaN
# 1299       50       18      NaN       108        56       NaN      NaN
# 1536       50       24      NaN       110        44       NaN      NaN
# 1760       50       46      NaN       111        25       NaN      NaN
# 1890       50       10      NaN       108        54       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 1150       50       27      NaN       108        38       NaN      NaN
# 1396       55       51      NaN       118        58       NaN      NaN
# 2116       52       29      NaN       117        32      50.0      NaN
# 2973       63       45      NaN       143        30       NaN      NaN
# 4077       70        3      NaN       140         7       NaN      NaN
#
#                    type_granite  time                       massif  \
# ...

# %%
time_df.to_excel("../_results/time_fix_initial.xlsx")
time_df.to_excel("../_results/working_data_initial.xlsx")

# %% [markdown]
# -----

# %% [markdown]
# # further subdivision of time classification

# %%
time1_df = pd.read_excel("../_results/working_data_initial.xlsx", index_col=0)

# %%
time1_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 512        50       15      NaN       109        11       NaN      NaN
# 1299       50       18      NaN       108        56       NaN      NaN
# 1536       50       24      NaN       110        44       NaN      NaN
# 1760       50       46      NaN       111        25       NaN      NaN
# 1890       50       10      NaN       108        54       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 1150       50       27      NaN       108        38       NaN      NaN
# 1396       55       51      NaN       118        58       NaN      NaN
# 2116       52       29      NaN       117        32      50.0      NaN
# 2973       63       45      NaN       143        30       NaN      NaN
# 4077       70        3      NaN       140         7       NaN      NaN
#
#                    type_granite  time                       massif  \
# ...

# %%
time1_df.loc[:, 'time']
time1_df.iloc[:, 8].value_counts().to_excel("../_RESULTS/time_counts.xlsx")

# %%
classification_renaming_dict = {"K1" : "K",
                                "K2" : "K",
                                "J1" : "J",
                                "J2" : "J",
                                "J3" : "J",
                                "J1-J2" : "J",
                                "J2-J3" : "J",
                                "J-K" : "K",
                                "K2-Pg" : "Pg"}

# %%
time1_df['time'] = time1_df['time'].replace(classification_renaming_dict)

# %%
time1_df.iloc[:, 8].value_counts().to_excel("../_RESULTS/time_counts.xlsx")

# %%
time1_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 512        50       15      NaN       109        11       NaN      NaN
# 1299       50       18      NaN       108        56       NaN      NaN
# 1536       50       24      NaN       110        44       NaN      NaN
# 1760       50       46      NaN       111        25       NaN      NaN
# 1890       50       10      NaN       108        54       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 1150       50       27      NaN       108        38       NaN      NaN
# 1396       55       51      NaN       118        58       NaN      NaN
# 2116       52       29      NaN       117        32      50.0      NaN
# 2973       63       45      NaN       143        30       NaN      NaN
# 4077       70        3      NaN       140         7       NaN      NaN
#
#                    type_granite  time                       massif  \
# ...

# %%
time1_df.to_excel("../_results/time_fix.xlsx")
time1_df.to_excel("../_results/working_data.xlsx")
