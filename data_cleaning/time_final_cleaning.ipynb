# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
time_df = pd.read_excel("../_results/text_temp_cleaned_handmatig_finalversion.xlsx", index_col=0)

# %%
time_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 1          44       31     30.0       138        37      30.0      NaN
# 2          54       12     10.0       119        24       NaN      NaN
# 3          62       36      NaN       155        36       NaN      NaN
# 4          61       35      NaN       146         2       NaN      NaN
# 5          68       55      NaN       164        24       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 4655       66       42      NaN       164        23       NaN      NaN
# 4656       46       56     30.0       137         5       3.0      NaN
# 4657       58       12      NaN       138        12       NaN      NaN
# 4658       60       51      NaN       147        31       NaN      NaN
# 4659       66       19      NaN       165        30       NaN      NaN
#
#                             type_granite time                      massif  \
# ...

# %%
time_df.loc[:, 'time']
time_df.iloc[:, 7].value_counts().to_excel("../_RESULTS/time_counts.xlsx")

# %%
classification_renaming_dict = {"J 1_2" : "J1-J2",
                                "K1-K2" : "K",
                                "Mz1" : "Mz",
                                "Mz3" : "Mz",
                                "K2-Pg1" : "K2-Pg",
                                "K2_Pg" : "K2-Pg",
                                "Pg3" : "Pg",
                                "Pg2" : "Pg",
                                "Pg1_2" : "Pg",
                                "J-Pg3" : "J-K",
                                "Pg2_3" : "Pg",
                                "J3-Pg1" : "J-K",
                                "J-Pg" : "J-K",
                                "Tr1-J1" : "Tr-J",                             
                                "J2-K" : "J-K",
                                "J3-K1" : "J-K",
                                "J3-Pg" : "J-K",
                                "Tr3-J" : "Tr-J",
                                "Tr-J2" : "Tr-J",
                                "Tr1" : "Tr",
                                "Tr2_3" : "Tr",
                                "Tr2" : "Tr",
                                "Tr3" : "Tr",
                                "K1_2" : "K",
                                "Pg1" : "Pg",
                                "Tr3-J1" : "Tr-J",
                                "Tr-J1" : "Tr-J",
                                "J2_3" : "J2-J3",
                                "J1_2" : "J1-J2"}

# %%
time_df['time'] = time_df['time'].replace(classification_renaming_dict)

# %%
time_df.iloc[:, 8].value_counts().to_excel("../_RESULTS/time_counts.xlsx")

# %%
time_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 1          44       31     30.0       138        37      30.0      NaN
# 2          54       12     10.0       119        24       NaN      NaN
# 3          62       36      NaN       155        36       NaN      NaN
# 4          61       35      NaN       146         2       NaN      NaN
# 5          68       55      NaN       164        24       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 4655       66       42      NaN       164        23       NaN      NaN
# 4656       46       56     30.0       137         5       3.0      NaN
# 4657       58       12      NaN       138        12       NaN      NaN
# 4658       60       51      NaN       147        31       NaN      NaN
# 4659       66       19      NaN       165        30       NaN      NaN
#
#                             type_granite time                      massif  \
# ...

# %%
time_df.to_excel("../_results/time_fix.xlsx")
time_df.to_excel("../_results/working_data.xlsx")
