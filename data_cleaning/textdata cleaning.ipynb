# %% [markdown]
# ## importing data and functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Vist_text_df = pd.read_excel("../_NEEDS_CLEANING/text_matches.xlsx", index_col=1).drop("Unnamed: 0", axis=1)

# %%
Vist_text_df
# Out:
#       1   2    3    4   5     6    7                                   8   \
# 0
# 1     44  31   30  138  37  30.0  NaN                   Granite alaskitic
# 2     54  12   10  119  24   NaN  NaN                 Granite leucocratic
# 3     62  36  NaN  155  36   NaN  NaN  Granite leucocratic coarse-grained
# 4     61  35  NaN  146  02   NaN  NaN                 Granite leucocratic
# 5     68  55  NaN  164  24   NaN  NaN    Granite-porphyry micropegmatitic
# ...   ..  ..  ...  ...  ..   ...  ...                                 ...
# 4655  66  42  NaN  164  23   NaN  NaN                             Diorite
# 4656  46  56   30  137  05   3.0  NaN                      Quartz diorite
# 4657  58  12  NaN  138  12   NaN  NaN                             Diorite
# 4658  60  51  NaN  147  31   NaN  NaN                             Diorite
# 4659  66  19  NaN  165  30   NaN  NaN                             Diorite
#
# ...

# %% [markdown]
# ## changing names of the columns

# %%
# Dictionary of old column names (as keys) and new column names (as values)
column_names = {1 : "Lat_deg",
                2 : "Lat_min",
                3 : "Lat_sec",
                4 : "Long_deg",
                5 : "Long_min",
                6 : "Long_sec",
                7 : "past_mer",
                8 : "type_granite",
                9 : "time",
                10 : "massif",
                11 : "?",  # analyst name
                12 : "others",
                13 : "sampler+year"}

# %%
# Replace the column names all at once instead of column per column
Vist_text_df = Vist_text_df.rename(column_names, axis=1)

# %% [raw]
# Vist_text_df = Vist_text_df.rename({1 : "Lat_deg"}, axis=1)
# Vist_text_df = Vist_text_df.rename({2 : "Lat_min"}, axis=1)
# Vist_text_df = Vist_text_df.rename({3 : "Lat_sec"}, axis=1)

# %% [raw]
# Vist_text_df = Vist_text_df.rename({4 : "Long_deg"}, axis=1)
# Vist_text_df = Vist_text_df.rename({5 : "Long_min"}, axis=1)
# Vist_text_df = Vist_text_df.rename({6 : "Long_sec"}, axis=1)
# Vist_text_df = Vist_text_df.rename({7 : "past_mer"}, axis=1)

# %% [raw]
# Vist_text_df = Vist_text_df.rename({8 : "type_granite"}, axis=1)
# Vist_text_df = Vist_text_df.rename({9 : "time"}, axis=1)
# Vist_text_df = Vist_text_df.rename({10 : "massif"}, axis=1)
# Vist_text_df = Vist_text_df.rename({11 : "?"}, axis=1)
# Vist_text_df = Vist_text_df.rename({12 : "others"}, axis=1)
# Vist_text_df = Vist_text_df.rename({13 : "sampler+year"}, axis=1)

# %%
Vist_text_df
# Out:
#      Lat_deg Lat_min Lat_sec Long_deg Long_min  Long_sec past_mer  \
# 0
# 1         44      31      30      138       37      30.0      NaN
# 2         54      12      10      119       24       NaN      NaN
# 3         62      36     NaN      155       36       NaN      NaN
# 4         61      35     NaN      146       02       NaN      NaN
# 5         68      55     NaN      164       24       NaN      NaN
# ...      ...     ...     ...      ...      ...       ...      ...
# 4655      66      42     NaN      164       23       NaN      NaN
# 4656      46      56      30      137       05       3.0      NaN
# 4657      58      12     NaN      138       12       NaN      NaN
# 4658      60      51     NaN      147       31       NaN      NaN
# 4659      66      19     NaN      165       30       NaN      NaN
#
#                             type_granite time                      massif  \
# 0
# 1                      Granite alaskitic   K2                         NaN
# ...

# %%
Vist_text_df.to_excel("../_RESULTS/text_temp_cleaned_df.xlsx")

# %% [markdown]
# # cleaning type column

# %% [markdown]
# ## first cleaning session (granite_type)

# %%
Vist_type_df = pd.read_excel("../_RESULTS/text_temp_cleaned_df.xlsx", index_col=0)

# %%
Vist_type_df.loc[:, 'type_granite']
Vist_type_df.iloc[:, 7].value_counts().to_excel("../_RESULTS/classification_counts.xlsx")

# iloc = always workng with the index, not the name, thats why 7 is used (python starts counting from 0)

# %%
classification_renaming_dict = {"Granite l eucocratic alkaline" : "Granite leucocratic alkaline",
                                "~Graniteo J" : "Granite",
                                "Granodiorite unevengrained" : "Granodiorite uneven-grained",
                                "Granite(granodiorite)medium-grained" : "Granite(granodiorite) medium-grained",
                                "Granite coarse-gra i ned" : "Granite coarse-grained",
                                "0 Bt granite porphyraceous" : "Bt granite porphyraceous",
                                "Granite porphyraceous med iu~ -gra ined" : "Granite porphyraceous medium-grained",
                                "Granite leucocratic alkal ine" : "Granite leucocratic alkaline",
                                "Hb-Bt granite unevengrained": "Hb-Bt granite uneven-grained",
                                "Granite leucocratic medium-gra ined" : "Granite leucocratic medium-grained",
                                "Granite alkalline" : "Granite alkaline",
                                "Granosyenite(granogiorite)" : "Granosyenite(granodiorite)",
                                "Hb-Bt granite med i um-grained": "Hb-Bt granite medium-grained",
                                "Diorite porphyr i te" : "Diorite porphyrite",
                                "Granite subalkal i ne" : "Granite subalkaline",
                                "Bt granit~porphyraceous" : "Bt granite porphyraceous",
                                "Granosye~ite(aplite) " : "Granosyeite(aplite)",
                                "Bt grantte coarse-grained" : "Bt granite coarse-grained",
                                "Gran ite leucocratic coarse-gra i ned" : "Granite leucocratic coarse-grained",
                                "Bt granite f ine-gra ined" : "Bt granite fine-grained",
                                "Granite porphyraceous medium-coar~e-grained" : "Granite porphyraceous medium-coarse-grained",
                                "Granite(granosyenite)fine-grained": "Granite(granosyenite) fine-grained",
                                "Bt gran i te porphyraceous" : "Bt granite porphyraceous",
                                "Granite fine-med i um-grained" : "Granite fine-medium-grained",
                                "~Bt granite porphyraceous medium-grained" : "Bt granite porphyraceous medium-grained",
                                "Bt granite medium-gra i ned" : "Bt granite medium-grained",
                                "Bt-Hb granodioriteo Tr" : "Bt-Hb granodiorite",
                                "Bt gran i te coarse-grained" : "Bt granite coarse-grained",
                                "Bt g~anite": "Bt granite",
                                "Bt granite porphyrateous" : "Bt granite porphyraceous",
                                "Granite porphyraceouso Tr" : "Granite porphyraceous",
                                "Granite m~dium-grained" : "Granite medium-grained",
                                "~Bt-Hb granodiori te" : "Bt-Hb granodiorite",
                                "Granite leucocratic~orphyraceous" : "Granite leucocratic porphyraceous",
                                "Granite~porphyry" : "Granite-porphyry",
                                "Granodiorite o Tr" : "Granodiorite",
                                "Bf granite-porphyry" : "Bt granite-porphyry",
                                "Granite alka~ine" : "Granite alkaline",
                                "~Granite leucocratic" : "Granite leucocratic",
                                "Granite leucocratic medi um-grained" : "Granite leucocratic medium-grained",
                                "0 Granodiorite" : "Granodiorite",
                                "Granite(granosyenite)alkaline" : "Granite(granosyenite) alkaline",
                                "0 Granite alaskitic" : "Granite alaskitic",
                                "0 Bt-Hb granite" : "Bt-Hb granite",
                                "Bt granit~fine-grained" : "Bt granite fine-grained",
                                "Granod i orite-porphyry" : "Granodiorite-porphyry",
                                "Gran i te coarse-grained" : "Granite coarse-grained",
                                "0 Hb-Bt granodiorite" : "Hb-Bt granodiorite",
                                "Granodidrite" : "Granodiorite",
                                "Two mica granite uneven grained" : "Two mica granite uneven-grained",
                                "~Alaskite" : "Alaskite",
                                "Bt granite leucocrat ic" :"Bt granite leucocratic",
                                "Granite l eucocratic medium-grained" :"Granite leucocratic medium-grained",
                                "0 Quartz diorite melanocratic" : "Quartz diorite melanocratic",
                                "Granodiorite(quartz diorite)coarse-grained" : "Granodiorite(quartz diorite) coarse-grained",
                                "Adamellite~porphyraceous" : "Adamellite porphyraceous",
                                "Gran i te alkaline" : "Granite alkaline",
                                "Granite leucocratic co~rse-grained" : "Granite leucocratic coarse-grained",
                                "Gr~ite alkaline fine-grained" : "Granite alkaline fine-grained",
                                "Bt granite uneveng~ained" : "Bt granite uneven-grained", 
                                "_-Granite subalkaline" : "Granite subalkaline",
                                "Gran i te gneissose" : "Granite gneissose",
                                "Granite fine~medium-grained" : "Granite fine-medium-grained",
                                "Gr~nit~~porphyry" : "Granite-porphyry",
                                "Granite(granodiorite)fine-grained" : "Granite(granodiorite) fine-grained",
                                "Granite-porphyry leucocrat ic" : "Granite-porphyry leucocratic",
                                "Granite subalkal i ne miarolitic" : "Granite subalkal i ne miarolitic",
                                "Granite-porphyry?lkaline" : "Granite-porphyry alkaline",
                                "Granite(adamellit e) " : "Granite(adamellite)", 
                                "~Adamellite" : "Adamellite",
                                "Granodiorite(granite)medium-grained" : "Granodiorite(granite) medium-grained",
                                "Quart z monzonite" : "Quartz monzonite",
                                "Bt-Hb granodior i te" : "Bt-Hb granodiorite", 
                                "Gran i t e leucocrat ic" : "Granite leucocrat ic",
                                "Granodior ite" : "Granodiorite",
                                "Granite-alkaline" : "Granite alkaline",
                                "Bt-Amf granodiorite~K" : "Bt-Amf granodiorite",
                                "Granit e porphyraceous" : "Granite porphyraceous",
                                "Bt granosyen i te" : "Bt granosyenite",
                                "Bt-Amf granosyenite (granodiorite)" : "Bt-Amf granosyenite(granodiorite)",
                                "Granodiorite micropegmatit ic" : "Granodiorite micropegmatitic",
                                "Bt granite medi~m-grained" : "Bt granite medium-grained",
                                "~Morion-granite" : "Morion-granite",
                                "Hb-Bt granite(granodiorite)porphyraceous medium-grained" : "Hb-Bt granite(granodiorite) porphyraceous medium-grained",
                                "0 Granodiorite-porphyry" : "Granodiorite-porphyry",
                                "Gran i~e coarse-grained" : "Granite coarse-grained",
                                "Bt gran ite" : "Bt granite",
                                "0 Granosyenite(gabbro-diorite)" : "Granosyenite(gabbro-diorite)",
                                "0 Granite-porphyry" : "Granite-porphyry",
                                "Granite~ubalkaline" : "Granite subalkaline",
                                "Granite coar se-grained" : "Granite coarse-grained",
                                "_Bt granite" : "Bt granite",
                                "Graniteporphyry" : "Granite-porphyry",
                                "Granodiorite porphyraceous medium-grained unevengrained" : "Granodiorite porphyraceous medium-grained uneven-grained",
                                "Bt granodior i t e" : "Bt granodiorite",
                                "Bt granite(granosyenite)porphyraceous" : "Bt granite(granosyenite) porphyraceous",
                                "Granite l~ucocratic" : "Granite leucocratic",
                                "Granite alaskit ic" : "Granite alaskitic",
                                "Granodior i te" : "Granodiorite",
                                "Granosyenite(granite)leucocratic porphyraceous" : "Granosyenite(granite) leucocratic porphyraceous",
                                "Apl ite" : "Aplite",
                                "Bt gran i te" : "Bt granite",
                                "Granodior~te" : "Granodiorite",
                                "Granite leucocratic f i ne-grained" : "Granite leucocratic fine-grained",
                                "Hb-Bt gran ite" : "Hb-Bt granite",
                                "Bt-Amf dior i te" : "Bt-Amf dioite",
                                "Granite-porph~ry" : "Granite-porphyry",
                                "Granite(granosyenite)porphyraceous" : "Granite(granosyenite) porphyraceous",
                                "Bt-Hb adamell i te" : "Bt-Hb adamellite",
                                "0 Bt granite medium-grained" : "Bt granite medium-grained",
                                "Bt granite'medium-grained" : "Bt granite medium-grained",
                                "Granite J" : "Granite",
                                "Dior i te" : "Diorite",
                                "Granite coarse-gr~ined" : "Granite coarse-grained",
                                "o Granite-porphyry" : "Granite-porphyry",
                                "Bt granodiorite medium-graine~" : "Bt granodiorite medium-grained",
                                "Granite alaskitico " : "Granite alaskitic",
                                "G-ranodiorite-porphyry" : "Granodiorite-porphyry",
                                "-Granite-porphyry" : "Granite-porphyry",
                                "~tgranite" : "granite",
                                "Bt gran ite medium-grained" : "Bt granite medium-grained",
                                "_Bt granite porphyraceous" : "Bt granite porphyraceous",
                                "Granite evengrained" : "Granite even-grained",
                                "0 Granite fine-grained" : "Granite fine-grained",
                                "Bt granodiorite(granite)porphyraceous coarse-grained" : "Bt granodiorite(granite) porphyraceous coarse-grained",
                                "Q~artz monzonite" : "Quartz monzonite",
                                "Grani~e leucocratic" : "Granite leucocratic",
                                "~ranodiorite" : "Granodiorite",
                                "G~anite coarse-grained" : "Granite coarse-grained",
                                "Gianite" : "Granite",
                                "Granite leucocratic~ine-grained" : "Granite leucocratic fine-grained",
                                "Granita leucocratic" : "Granite leucocratic",
                                "Quartz dior ite" : "Quartz diorite",
                                "Granite subalkiline" : "Granite subalkaline",
                                "Hb-Bt gra~odiorite" : "Hb-Bt granodiorite",
                                "Mu granite porphyraceous evengrained" :"Mu granite porphyraceous even_grained",
                                "Granite leucocratic sublkaine" : "Granite leucocratic sublkaline",
                                "Adamel lite" : "Quartz monzonite", 
                                "Bt gran ite porphyraceous medium-f i ne-grained" : "Bt granite porphyraceous medium-fine-grained",
                                "Gra~ite coarse-grained" : "Granite coarse-grained",
                                "Gran~te-porphyry" : "Granite-porphyry",
                                "Bt-Mu granite_ medium-grained" : "Bt-Mu granite medium-grained",
                                "Two mic~granite coarse-grained" : "Two mica granite coarse-grained",
                                "Gra~odiorite medium-grained" : "Granodiorite medium-grained",
                                "Hb quartz diori t e" : "Hb quartz diorite",
                                "Hb-Bt granosyenite(granite)porphyraceous" : "Hb-Bt granosyenite(granite) porphyraceous",
                                "Two mica" : "Two mica granite coarse-grained",
                                "~Diorite" : "Diorite",
                                "Bt-Hb granosyenite (granodiorite)porphyraceous" : "Bt-Hb granosyenite(granodiorite) porphyraceous",
                                "Quartz dioriteo Tr" : "Quartz diorite",
                                "Granit e-porphyry" : "Granite porphyry",
                                "Granit~" : "Granite",
                                "Adamell~te" : "Quartz monzonite",
                                "Hb-Bt gran i te" : "Hb-Bt granite",
                                "Bt-Mu graniteo" : "Bt-Mu granite",
                                "Granosyenite-porphyry o Tr" : "Granosyenite-porphyry",
                                "Granite fine~grained" : "Granite fine-grained",
                                "Gr an i te leucocratic" : "Granite leucocratic",
                                "Bt-Hb granod iorite medium-grained" : "Bt-Hb granodiorite medium-grained",
                                "Diori te" : "Diorite",
                                "Granite leucocratic medium-gra i ned" : "Granite leucocratic medium-grained",
                                "Gran i te leucocratic fine-medium-grained" : "Granite leucocratic fine-medium-grained",
                                "Granite leucocratic medium-grainedo" : "Granite leucocratic medium-grained",
                                "_Granodiorite" : "Granodiorite",
                                "Bt-Mu grani~e fine-grained" : "Bt-Mu granite fine-grained",
                                "Granite fine-grained evengrained" : "Granite fine-grained even-grained",
                                "Granite leucocratic subalkal ine" : "Granite leucocratic subalkaline",
                                "Grinite alkaline~Tr" : "Granite alkaline",
                                "Granite miarol itic" : "Granite miarolitic",
                                "Granite porphyraceous f i ne-grained" : "Granite porphyraceous fine-grained",
                                "Bt granit e" : "Bt granite",
                                "Granodiori te porphyraceous" : "Granodiorite porphyraceous",
                                "Hb-Bt granite(adamellite)" : "Hb-Bt granite(quartz monzonite)",
                                "0 Granite leucoc~~~ic" : "Granite leucocratic", 
                                "G~anite leucocratic medium-grained" : "Granite leucocratic medium-grained",
                                "Bt granite leucocratic medium-gr~ined" : "Bt granite leucocratic medium-grained",
                                "Gran i te medium-grained" : "Granite medium-grained",
                                "~Granite" : "Granite",
                                "Granite l eucocratic" : "Granite leucocratic",
                                "Granodior i te-porphyry" : "Granodiorite-porphyry",
                                "Quartz dior i te" : "Quartz diorite",
                                "Granit e" : "Granite",
                                "Granite alkal ine" : "Granite alkaline",
                                "Gran i te-porphyry" : "Granite-porphyry",
                                "0 Quartz diorite" : "Quartz diorite",
                                "~Granite porphyraceous" :"Granite porphyraceous",
                                "Gran i te leucocratic" : "Granite leucocratic",
                                "Gran i te fine-grained" : "Granite fine-grained",
                                "Granite alaski tic" : "Granite alasktic",
                                "Granit e coarse-grained" : "Granite coarse-grained",
                                "Granite leucocratic unevengrained" : "Granite leucocratic uneven-grained",
                                "Bt granosyenite(granite)porphyraceous" : "Bt granosyenite(granite) porphyraceous",
                                "Granite leucocrat ic" : "Granite leucocratic",
                                "0 Diorite" : "Diorite",
                                "Granod iorite" :"Granodiorite",
                                "Bt granite unevengrained" : "Bt granite uneven-grained",
                                "Granosyenite(granodiorite)porphyraceous" : "Granosyenite(granodiorite) porphyraceous",
                                "Granosyenite(granite)porphyraceous" : "Granosyenite(granite) porphyraceous",
                                "Granite unevengrained" : "Granite uneven-grained",
                                "Bt granite evengrained" : "Bt granite even-grained",
                                "Granodiori te" : "Granodiorite",
                                "Granodiorit e" : "Granodiorite",
                                "Granodiorite medium-grained unevengrained" : "Granodiorite medium-grained uneven-grained",
                                "Gran i te" : "Granite",
                                "Bt-Hb" : "Bt-Hb Granodiorite medium-grained"}

# %%
# %%time
Vist_type_df['type_granite'] = Vist_type_df['type_granite'].replace(classification_renaming_dict)
# Out:
# Wall time: 39.9 ms

# %%
Vist_type_df
# Out:
#      Lat_deg Lat_min Lat_sec Long_deg Long_min  Long_sec past_mer  \
# 1         44      31      30      138       37      30.0      NaN
# 2         54      12      10      119       24       NaN      NaN
# 3         62      36     NaN      155       36       NaN      NaN
# 4         61      35     NaN      146       02       NaN      NaN
# 5         68      55     NaN      164       24       NaN      NaN
# ...      ...     ...     ...      ...      ...       ...      ...
# 4655      66      42     NaN      164       23       NaN      NaN
# 4656      46      56      30      137       05       3.0      NaN
# 4657      58      12     NaN      138       12       NaN      NaN
# 4658      60      51     NaN      147       31       NaN      NaN
# 4659      66      19     NaN      165       30       NaN      NaN
#
#                             type_granite time                      massif  \
# 1                      Granite alaskitic   K2                         NaN
# ...

# %%
Vist_type_df.to_excel("../_RESULTS/text_temp_cleaned_df.xlsx")

# %%
Vist_type_df.loc[:, 'type_granite']
Vist_type_df.iloc[:, 7].value_counts().to_excel("../_RESULTS/classification_counts_new.xlsx")

# %% [markdown]
# ## second cleaning session (granite_type)

# %%
classification_renaming_dict2 = {"Granite l eucocratic alkaline" : "Granite leucocratic alkaline",
                                "Granite morionic" : "Granite",
                                "Granite alkaline morionic" : "Granite alkaline",
                                "Granite(granophyre) " : "Granite(granophyre)",
                                "Graryite" : "granite",
                                "Granosyertite" : "Granosyenite",
                                "Granite-porphyry micropegmatitico" : "Granite-porphyry micropegmatitic",
                                "Granite eraption breccia" : "Granite eruption breccia",
                                "Granite andesinic" : "Granite andesitic",
                                "Granite alkaline leucocratico " : "Granite alkaline leucocratic",
                                "Granite-porphyryo " : "Granite-porphyry",
                                "Graniteo J" : "Granite",
                                "Granite melanocrat ic" : "Granite melanocratic",
                                "Granite " : "Granite",
                                "Granite(granosyenite) " : "Granite(granosyenite)",
                                "Granodiorite(quartz diorite) " : "Granodiorite(quartz diorite)",
                                "Amf-Bt plagiogranite(granite) " : "Amf-Bt plagiogranite(granite)",
                                "Granite subalkaline " : "Granite subalkaline",
                                "Two mica granite coarse-grained " : "Two mica granite coarse-grained",
                                "Granosyenite-porphyry (granite-porphyry) " : "Granosyenite-porphyry (granite-porphyry)",
                                "Granosyenite(granite subalkaline) " : "Granosyenite(granite subalkaline)",
                                "Granite-porphyry " : "Granite-porphyry",
                                "Granosyenite " : "Granosyenite",
                                "Granite leucocratic porphyraceous " : "Granite leucocratic porphyraceous",
                                "Tonalite(quartz diorite) " : "Tonalite(quartz diorite)",
                                "Plagiogranite(quartz diorite) " : "Plagiogranite(quartz diorite)",
                                "Granite alkaline(granosyenite) " : "Granite alkaline(granosyenite)",
                                "Aplite " : "Aplite",
                                "Bt-Mu granite " : "Bt-Mu granite",
                                "granite" : "Granite",
                                "Granodiorite " : "Granodiorite",
                                "Granite leucocratic " : "Granite leucocratic",
                                "Bt-Amf granosyenite(granodiorite) " : "Bt-Amf granosyenite(granodiorite)"}

# %%
Vist_type_df['type_granite'] = Vist_type_df['type_granite'].replace(classification_renaming_dict2)

# %%
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("Alaskite", "Leucogranite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("alaskite", "leucogranite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("alaskitic", "leucogranitic")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("alasktic", "leucogranitic")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("leucoganitic", "leucocratic")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("alaskitoid", "leucogranitoid")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("Adamellite", "Quartz monzonite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("adamellite", "quartz monzonite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("Granophire", "Granophyre")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("dioite", "diorite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("granodirite", "granodiorite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("_", "-")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("leucocrat ic", "leucocratic")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("graniteo", "granite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("subalkal i ne", "subalkaline")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("Granosyeite", "Granosyenite")
Vist_type_df['type_granite']  = Vist_type_df['type_granite'].str.replace("miarolitic", "miarolic")
# Out:
# Wall time: 63.8 ms

# %%
Vist_type_df
# Out:
#      Lat_deg Lat_min Lat_sec Long_deg Long_min  Long_sec past_mer  \
# 1         44      31      30      138       37      30.0      NaN
# 2         54      12      10      119       24       NaN      NaN
# 3         62      36     NaN      155       36       NaN      NaN
# 4         61      35     NaN      146       02       NaN      NaN
# 5         68      55     NaN      164       24       NaN      NaN
# ...      ...     ...     ...      ...      ...       ...      ...
# 4655      66      42     NaN      164       23       NaN      NaN
# 4656      46      56      30      137       05       3.0      NaN
# 4657      58      12     NaN      138       12       NaN      NaN
# 4658      60      51     NaN      147       31       NaN      NaN
# 4659      66      19     NaN      165       30       NaN      NaN
#
#                             type_granite time                      massif  \
# 1                  Granite leucogranitic   K2                         NaN
# ...

# %%
Vist_type_df.loc[:, 'type_granite']
Vist_type_df.iloc[:, 7].value_counts().to_excel("../_RESULTS/classification_counts_new.xlsx")

# %%
Vist_type_df.to_excel("../_RESULTS/text_temp_cleaned_df.xlsx")

# %% [markdown]
# ## first cleaning  session (age)

# %%
Vist_age_df = pd.read_excel("../_RESULTS/text_temp_cleaned_df.xlsx", index_col=0)

# %%
Vist_age_df.loc[:, 'time']
Vist_age_df.iloc[:, 8].value_counts().to_excel("../_RESULTS/age_counts.xlsx")

# %%
classification_renaming_dict3 = {"granitecoarse-grained" : "J3",
                                "K2oI" : "K2",
                                "TroD" : "Tr",
                                "K2'" : "K2",
                                "Tatiba-Armin" : "",
                                "J2o" : "J2",
                                "T3-J1" : "Tr3-J1",
                                "Tr-JoKontalakan" :"Tr-J",
                                "Det" : "J",
                                "Onchon" : "J",
                                "K2-Pg10BykovaoOth" : "K2-Pg1",
                                "Ji_2" : "J1_2",
                                "x2" : "K2",
                                "L" : "Tr",
                                "K2Lanskayaintrusion" : "K2",
                                "J3oDeras-" : "J3",
                                "K1Magadanbatholite" : "K1",
                                "Granodioritemedium-grained" : "K1",
                                "Yuryung" : "K",
                                "Mz1N" : "Mz1-N",
                                "K2E" : "K2",
                                "J1_2oloMoBender" : "J1_2",
                                "K'" : "K",
                                "J3Det" : "J3",
                                "K1oloS" : "K1",
                                "Ki" : "K",
                                "K2-Pg10" : "K2-Pg1",
                                "J1_2o" : "J1_2",
                                "'leucocraticmedium-grained" : "J 1_2",
                                "LI" :"J1",
                                "Ji" : "J1",
                                "K1oUlakhan" : "K1",
                                "Tr~-J'" : "Tr-J",
                                "J3-K1o" :"J3-K1",
                                "J'" : "J",
                                "JI" : "J1",
                                "A" : "Tr",
                                "T" : "Tr",
                                "porphyraceous" : "K2",
                                "K2o" : "K2",
                                "~K1" : "K1",
                                "Tr-JI" : "Tr-J1",
                                "D" : "Tr",
                                "J 1_2" : "J1_2",
                                "Ki'" : "K1",
                                "K1o" : "K1",
                                "Tr3-J1-N" : "Tr3-J1"}

# %%
# %%time
Vist_age_df['time'] = Vist_age_df['time'].replace(classification_renaming_dict3)
# Out:
# Wall time: 14 ms

# %%
Vist_age_df.to_excel("../_RESULTS/text_temp_cleaned_df.xlsx")

# %%
Vist_age_df
# Out:
#      Lat_deg Lat_min Lat_sec Long_deg Long_min  Long_sec past_mer  \
# 1         44      31      30      138       37      30.0      NaN
# 2         54      12      10      119       24       NaN      NaN
# 3         62      36     NaN      155       36       NaN      NaN
# 4         61      35     NaN      146       02       NaN      NaN
# 5         68      55     NaN      164       24       NaN      NaN
# ...      ...     ...     ...      ...      ...       ...      ...
# 4655      66      42     NaN      164       23       NaN      NaN
# 4656      46      56      30      137       05       3.0      NaN
# 4657      58      12     NaN      138       12       NaN      NaN
# 4658      60      51     NaN      147       31       NaN      NaN
# 4659      66      19     NaN      165       30       NaN      NaN
#
#                             type_granite time                      massif  \
# 1                  Granite leucogranitic   K2                         NaN
# ...

# %%
Vist_age_df.loc[:, 'time']
Vist_age_df.iloc[:, 8].value_counts().to_excel("../_RESULTS/age_counts_new.xlsx")

# %%
Vist_age_df.to_excel("../_RESULTS/text_temp_cleaned_df.xlsx")

# %% [markdown]
# ## first cleaning  session (massif)

# %%
Vist_massif_df = pd.read_excel("../_RESULTS/text_temp_cleaned_df.xlsx", index_col=0)

# %%
Vist_massif_df.loc[:, 'massif']
Vist_massif_df.iloc[:, 9].value_counts().to_excel("../_RESULTS/massif_counts.xlsx")

# %%
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("mass i f", "massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("m~ssif", "massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("~assif", " massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("mass~f", "massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("~massif", " massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("massiL", "massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("ma ssif", "massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("'massif", " massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("masstf", "massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("massif ", "massif")

Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("arekt in", "arektin")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Kontal akan", "Kontalakan")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Kontalakh", "Kontalakan")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("massif M", "massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Dzhalyndzh in massif", "Dzhalyndzhin massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Be~kem", "Bekkem")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Ust' -Nerchugan massif", "Ust'-Nerchugan massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Tro Ust'-Nerchugan", "Ust'-Nerchugan massif")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Ynnykh massif", "Ynnykh-Khaya")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("-J1Bomudzhe", "-Bomudzhe")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Tatiba Daln insky", "Tatiba Dalninsky")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("~Sinanchin", "Sinanchin")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Ta~bogatay ", "Tabogatay ")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("int rusion", "intrusion")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Left-", "")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Right-", "")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Rigth-", "")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("Middle-", "")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("K1", "")
Vist_massif_df['massif']  = Vist_massif_df['massif'].str.replace("mass!f", "massif")

# %%
classification_renaming_dict4 = {"Iul~tin massif" : "Iul'tin massif",
                                "~Utuy massif" : "Utuy massif",
                                "-Khayrkhan massif" : "Khayrkhan massif",
                                ":ji U~per-Buy massif" : "Upper-Buy massif",
                                ":Kurulgin massif" : "Kurulgin massif",
                                ":Unegetin massif" : "Unegetin massif",
                                "Ulakhan- ~~s massif" : "Ulakhan-Sis massif",
                                "Ulakhan-S is massif" : "Ulakhan-Sis massif",
                                "~Ulakhan-Sis massif" : "Ulakhan-Sis massif",
                                "Ulakhan massif" : "Ulakhan-Sis massif",
                                "Ku r ein massif" : "Kurein massif",
                                "-Tatiba massif" : "Tatiba massif",
                                "-Dzhisa-Khid massif" :"Dzhisa-Khid massif",
                                "Dusse-Alin'intrusion" : "Dusse-Alin massif",
                                "Pgo Mutukhin Oprichnin massif" : "Pgo Mutukhin Oprichnin massif",
                                "Mutukhin Oprichn in massif" :"Mutukhin Oprichnin massif",
                                "Mutukhin Opr ichnin massif" :"Mutukhin Oprichnin massif",
                                "Il lin-Emneken massif" : "Il'lin-Emneken massif",
                                "West-B~tugychag massif" : "West-Butugychag massif",
                                "-Butugychag massif" : "Butugychag massif",
                                "Vol okat uy stock" : "Volokatuy stock",
                                "-Khaarstan massif" : "Khaarstan massif",
                                "Alaskit ic massif" : "Alaskitic massif",
                                "Ve.rshino-Dukuvucha massif" : "Vershino-Dukuvucha massif",
                                "-Marektin massif" : "Kontalakan-Marektin massif",
                                "Zimov?e massifZimov?e massifZimo" : "Zimov'e massif",
                                "-Sis massif" : "Ulakhan-Sis massif",
                                "-Sukharin massif" : "Sukharin massif",
                                "Emnunkenygtun massif" : "Emnunkenigtun massif",
                                "Emnelen massif" : "Il'in-Emneken massif" ,
                                "Il'lin-Emneken massif" : "Il'in-Emneken massif",
                                "-Erikit massif" : "Erikit massif",
                                "-Tuostakh massif" : "Tuostakh massif",
                                "Khoboyotuu-Ech iy massif" : "Khoboyotuu-Echiy massif",
                                "Val entinovsky massif" : "Valentinovsky massif",
                                "Van~ou s massif" : "Vangous massif",
                                "-Khalyin massif" : "Khalyin massif",
                                "-Sukharnin massif" : "Sukharnin massif",
                                "Achchen massif" : "Achen massif",
                                "Amundzhikan massif" : "Amudzhikan massif",
                                "Anmannekan massif" : "Anmannykan massif",
                                "Arachinmassif" : "Arachin massif",
                                "Arakamiechen massif" : "Arakamchechen massif",
                                "Arangan massif" : "Arangas massif",
                                "Attykeveem massif" : "Attykveem massif",
                                "Barylly-Elakh massif" : "Baryllyelakh massif",
                                "Bezymyanny stock" : "Bezymyanny massif",
                                "Burguchan massif" :"Burgochan massif",
                                "Butakan massif" : "Butokan massif",
                                "Chikonkon massif" : "Chikokon massif",
                                "Chikonon massif" : "Chikokon massif",
                                "Chimalkin massif" : "Chimalgin massif",
                                "Chugul uk massif" : "Chuguluk massif",
                                "Dabat stock" : "Dabat massif",
                                "Darkhan-Arynnur massif" : "Darkhan-Aryn-Nur massif",
                                "Dotulur massif" : "Dolutur massif",
                                "Dulgalaakh-Chuochur massif" : "Dulgalakh-Chuochur massif",
                                "Dzhunbain massif" : "Dzunbain massif",
                                "Dzun-Bain massif" : "Dzunbain massif",
                                "East-Kondomin massif" : "East-Kandomin massif",
                                "East-Polousryy massif" : "East-Polousny massif",
                                "Ekachin massif" : "Ekachan massif",
                                "Ekechan massif" : "Ekachan massif",
                                "Ekitykinmassif" : "Ekitykin massif",
                                "Eldovak Orekhovsky massif" : "Eldovsky Orekhovy massif",
                                "Emkyrchan massif" : "Emkirchan massif",
                                "Endorok massif" : "Engorok massif",
                                "Erekit massif" : "Erikit massif",
                                "Garmandin massif" : "Garmondin massif",
                                "Garmondzhin massif" : "Garmondin massif",
                                "Gulakin massif" : "Gulanin massif",
                                "Ichatkin massif" : "Ichatka massif",
                                "Ikhe-Naragatin massif" : "Ikhe-Naratin massif",
                                "Iman-Sinanchin massif" : "Imano-Sinanchin massif",
                                "Kamenka stock" : "Kamenka massif",
                                "Kar sky massif" : "Karsky massif",
                                "Khadaranyin massif" : "Khadaran'in massif",
                                "Khaldan massif" : "Khalgan massif",
                                "Khalgin massif" : "Khalgan massif",
                                "Khangass massif" : "Khangas massif",
                                "Khapcheranga massif" : "Khapcheranga stock",
                                "Khargin massif" : "Kharchin massif",
                                "Khaytakchen massif" : "Khaytakhchen massif",
                                "Khaytakhchen Northen massif" : "Khaytakhchen massif",
                                "Khenikendzhin massif" : "Khenikandzhin massif",
                                "Khilganin massif" : "Khilgalin massif",
                                "Khoboyot uu-Echiy massif" : "Khoboyotuu-Echiy massif",
                                "Khoboyotuu-Echiy-massif" : "Khoboyotuu-Echiy massif",
                                "Khulimin Sakhatin massif" : "Khulimin Sakhotin massif",
                                "Ku ranakh-Salin massif" : "Kuranakh-Salin massif",
                                "Kutum massif" : "Kurum massif",
                                "Kyamb izin massif" : "Kyambizin massif",
                                "lampakhez massif" : "Lampakhez massif",
                                "Lampakhez Sadovsky massif" : "Lampakhez massif",
                                "Li s'in massif" : "Lis'in massif",
                                "Little-Tyllakh massif" : "Little Tyllakh massif",
                                "Marki massif" : "Marka massif",
                                "Mayloyt uy massif" : "Maylotuy massif",
                                "Medvedkin massif" : "Medvezhkin massif",
                                "Metegyn massif" : "Metechyn massif",
                                "Meyutkhey massif" : "Melyutkhey massif",
                                "Molokov massif" : "Molokovsky massif",
                                "Mukukhin Oprichnin massif" : "Mutukhin Oprichnin massif",
                                "Nebukhandzhin stock" : "Nebukhandzhin massif",
                                "Neksko-Gynykandzhin massif" : "Neksko-Gylykandzhin massif",
                                "Nel'gacy massif" : "Nelgasig massif",
                                "Nyuf-Ul'bey massif" : "Nyut-Ul'bey massif",
                                "Nyul kuchan massif" : "Nyulkuchan massif",
                                "Odinoky stock" : "Odinoky massif",
                                "Odomkan massif" : "Odonkan massif",
                                "Onnek massif" : "Onnekh massif",
                                "Onnyakh massif" : "Onnekh massif",
                                "Palyarr massif" : "Palyan massif",
                                "Peekaney massif" : "Peekeney massif",
                                "Pyrkanayan massif" : "Pyrkanay massif",
                                "Pyrkatachin massif" : "Pyrkatagyn massif",
                                "Pyrkhatagyn massif" : "Pyrkatagyn massif",
                                "Saken Chikhachevsky massif" : "Saken Chikhachev massif",
                                "Saken-massif" : "Saken massif",
                                "Sanchez Karavan massif" : "Sanchaz Karavan massif",
                                "-Seymkan massif" : "Seymkan massif",
                                "Shergoldzh in massif" : "Shergoldzhin massif",
                                "Sinanchinmassif" : "Sinanchin massif",
                                "Srednin massif" : "Sredninsky massif",
                                "Sretensky massif" : "Sreten massif",
                                "Sukharin massif" : "Sukharnin massif",
                                "Sulukhacha massif" : "Sulukhachan massif",
                                "Svetlin massif" : "Svetlinsky massif",
                                "Svyatoy massif" : "Svyatoy Nos massif",
                                "Tallalakh massif" : "Talalakh massif",
                                "Tankolyan massif" : "Tankolyakh massif",
                                "Tarbagannakh massif" : "Tarbaganakh massif",
                                "Taydet massif" :"Taydut massif",
                                "Telekay massifM" : "Telekay massif",
                                "Tenkeley massif" : "Tenkely massif",
                                "Tot khotoy massif" : "Totkhotoy massif",
                                "Totkotoy massif" : "Totkhotoy massif",
                                "Tungirikan massif" : "Tungirikan stock",
                                "Tur ak massif" : "Turak massif",
                                "Uguchan massif" : "Uchugan massif",
                                "Ulchen massif" : "Ul'chen massif",
                                "-Ul'chen massif" : "Ul'chen massif",
                                "Upper-Kuranak  massif" : "Upper-Kuranakh massif",
                                "~amir massif" : "Tamir massif",
                                "An i kin massif" : "Anikin massif",
                                "-Armin massif" : "Armin massif",
                                "Badzh i raevsky massif" : "Badzhiraevsky massif",
                                "Bilch i r massif" : "Bilchir massif",
                                "East:Polousryy massif" : "East-Polousryy massif",
                                "Ikh-Khayrkhan massif" : "Ikhe-Khayrkhan massif",
                                "Kandomi n massif" : "Kandomin massif",
                                "-Kandomin massif" : "Kandomin massif",
                                "-Kanelyveem massif" : "Kanelyveem massif",
                                "Ken massif" : "Kem massif",
                                "-Khalgin massif" : "Khalgin massif",
                                "-Khilganin massif" : "Khilgalin massif",
                                "-Khuluglin massif" : "Khuluglin massif",
                                "-Kuentin massif" : "Kyuentin massif",
                                "-Kyuentin massif" : "Kyuentin massif",
                                "-lchuveem massif" : "lchuveem massif",
                                "Little Tyllakh massif" : "Little Tyellakh massif",
                                "Lukhin massif" : "Luchin massif",
                                "-Myauchan massif" : "Myauchan massif",
                                "-Naratin massif" : "Naratin massif",
                                "-Ola massif" : "Ola massif",
                                "-Omuk massif" : "Omuk massif",
                                "-Philip massif" : "Philip massif",
                                "-Polousny massif" : "Polousny massif",
                                "Pytlyansky massif" : "Pytlyan massif",
                                "Samarta massifo MoloKodachigova" : "Samarta massif",
                                "Shellyupin massif" : "Shelyupin massif",
                                "Shirokopadnin massif" : "Shirokopadinsky massif",
                                "Shirokopadnin massif" : "Shirokopadinsky massif",
                                "-Sinanchin massif" : "Sinanchin massif",
                                "-Sudulin massif" : "Sudulin massif",
                                "Sukharin massif" : "Sukharnin massif",
                                "Tal akhtakh massif" : "Talakhtakh massif",
                                "-Tas massif" : "Tas massif",
                                "-Tyrin massif" : "Tyrin massif",
                                "-Tytmutin massif" : "Tytmutin massif",
                                "-Udoma massif" : "Udoma massif",
                                "-Ul'bey massif" : "Ul'bey massif",
                                "-Ulin massif" : "Ulin massif",
                                "Upper-Khandig massif" : "Upper-Khandyg massif",
                                "Ust'-Nerchugan massif massif" : "Ust'-Nerchugan massif",
                                "Valentinovs massif" : "Valentinovsky massif",
                                "Velitkinay massif" : "Velitkenay massif",
                                "Venilem Southern massif" : "Vennlem Southern massif",
                                "Vladi~irsky massif" : "Vladimirsky massif",
                                "Vladimirs massif" : "Vladimirsky massif",
                                "Vukvuney massif" : "Vukvunay massif",
                                "West-Kandemin massif" : "West-Kandomin massif",
                                "Yamutzin massif" : "Yamutinzin massif",
                                "Yanrapaak massif" : "Yanra-Paak massif",
                                "Ynnykh-Khaya" : "Ynnykh-Khaya massif",
                                "-Yuryakh massif" : "Yuryakh massif",
                                "Zhipkoshin stock" : "Zhipkoshin massif",
                                "Zymtsykhen massif" : "Zymtsikhen massif",
                                "-Chulutin massif" : "Tsagan-Chulutin massif",
                                "-Echiy massif" : "Khoboyotuu-Echiy massif",
                                "-Alin massif" : "Central Sikhote-Alin massif",
                                "-Dzhaur massif" : "Khutu-Dzhaur massif",
                                "-Bomudzhek massif" : "Bomudzhek massif"}

# %%
Vist_massif_df['massif'] = Vist_massif_df['massif'].replace(classification_renaming_dict4)

# %%
Vist_massif_df.loc[:, 'massif']
Vist_massif_df.iloc[:, 9].value_counts().to_excel("../_RESULTS/massif_new.xlsx")

# %%
Vist_massif_df.to_excel("../_RESULTS/text_temp_cleaned_df.xlsx")

# %% [markdown]
# ## first cleaning  session (sampler)

# %%
Vist_sampler_df = pd.read_excel("../_RESULTS/text_temp_cleaned_df.xlsx", index_col=0)

# %%
Vist_sampler_df.loc[:, '?']
Vist_sampler_df.iloc[:, 10].value_counts().to_excel("../_RESULTS/sampler_counts.xlsx")

# %%
Vist_sampler_df.loc[:, '?']
Vist_sampler_df.iloc[:, 10].value_counts().to_excel("../_RESULTS/sampler_counts_new.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-69307090d45a> in <module>
# ----> 1 Vist_sampler_df.loc[:, '?']
#       2 Vist_sampler_df.iloc[:, 10].value_counts().to_excel("../_RESULTS/sampler_counts_new.xlsx")
#
# NameError: name 'Vist_sampler_df' is not defined

# %% [markdown]
# ## coordinates

# %%
Vist_coordinates_df = pd.read_excel("../_RESULTS/text_temp_cleaned_handmatig2.xlsx").drop("Unnamed: 0", axis=1)

# %%
Vist_coordinates_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 0          44       31     30.0       138        37      30.0      NaN
# 1          54       12     10.0       119        24       NaN      NaN
# 2          62       36      NaN       155        36       NaN      NaN
# 3          61       35      NaN       146         2       NaN      NaN
# 4          68       55      NaN       164        24       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 4654       66       42      NaN       164        23       NaN      NaN
# 4655       46       56     30.0       137         5       3.0      NaN
# 4656       58       12      NaN       138        12       NaN      NaN
# 4657       60       51      NaN       147        31       NaN      NaN
# 4658       66       19      NaN       165        30       NaN      NaN
#
#                             type_granite time                      massif  \
# ...

# %%
Vist_coordinates_df.loc[:, 'Lat_deg']
Vist_coordinates_df.iloc[:, 0].value_counts().to_excel("../_RESULTS/Lat_deg_counts.xlsx")

# %%
Vist_coordinates_df.loc[:, 'Lat_min']
Vist_coordinates_df.iloc[:, 1].value_counts().to_excel("../_RESULTS/Lat_min_counts.xlsx")

# %%
Vist_coordinates_df.loc[:, 'Lat_sec']
Vist_coordinates_df.iloc[:, 2].value_counts().to_excel("../_RESULTS/Lat_sec_counts.xlsx")

# %%
Vist_coordinates_df.loc[:, 'Long_deg']
Vist_coordinates_df.iloc[:, 3].value_counts().to_excel("../_RESULTS/Long_deg_counts.xlsx")

# %%
Vist_coordinates_df.loc[:, 'Long_min']
Vist_coordinates_df.iloc[:, 4].value_counts().to_excel("../_RESULTS/Long_min_counts.xlsx")

# %%
Vist_coordinates_df.loc[:, 'Long_sec']
Vist_coordinates_df.iloc[:, 5].value_counts().to_excel("../_RESULTS/Long_sec_counts.xlsx")

# %%
Vist_coordinates_df.loc[:, 'past_mer']
Vist_coordinates_df.iloc[:, 6].value_counts().to_excel("../_RESULTS/past_mer_counts.xlsx")

# %%
to_change = list(Vist_coordinates_df[Vist_coordinates_df['Long_deg'] == '1~8'].index)
# Out:
# C:\Users\Sebastian\Anaconda3\envs\main\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
to_change
# Out:
# []

# %% [markdown]
# ### sampler and year

# %%
Vist_samyear_df = pd.read_excel("../_RESULTS/text_temp_cleaned_handmatig2.xlsx").drop("Unnamed: 0", axis=1)

# %%
Vist_samyear_df
# Out:
#       Lat_deg  Lat_min  Lat_sec  Long_deg  Long_min  Long_sec past_mer  \
# 0          44       31     30.0       138        37      30.0      NaN
# 1          54       12     10.0       119        24       NaN      NaN
# 2          62       36      NaN       155        36       NaN      NaN
# 3          61       35      NaN       146         2       NaN      NaN
# 4          68       55      NaN       164        24       NaN      NaN
# ...       ...      ...      ...       ...       ...       ...      ...
# 4654       66       42      NaN       164        23       NaN      NaN
# 4655       46       56     30.0       137         5       3.0      NaN
# 4656       58       12      NaN       138        12       NaN      NaN
# 4657       60       51      NaN       147        31       NaN      NaN
# 4658       66       19      NaN       165        30       NaN      NaN
#
#                             type_granite time                      massif  \
# ...

# %%
Vist_samyear_df.loc[:, 'sampler+year']
Vist_samyear_df.iloc[:, 12].value_counts().to_excel("../_RESULTS/samyear_cont.xlsx")

# %%
classification_renaming_dict10 = {"~.A.Matlashov,1969" : "A.A.Matlashov,1969",
                                  "~.A.Syas'ko,1969" : "A.A.Syas'ko,1969",
                                  "A.A.Syas'ko 9l969" : "A.A.Syas'ko,1969",
                                  "A.A.Syas'ko.1969" : "A.A.Syas'ko,1969",
                                  "~.P.Pet~ov,1945" : "R.P.Petrov,1945",
                                  "0.1.Myaskovsky" : "O.M.Myaskovsky",
                                  "1.1.Kozyrev,1968" : "1.1.Kozyrev,1968",
                                  "1.F.Grigor'ev,1957" : "I.F.Grigor'ev,1957",
                                  "1.I.Antushevich,1966" : "I.I.Antushevich,1966",
                                  "A oN.Efimov,1959" : "A.N.Efimov,1959",
                                  "A.A.Alekseev 9l968" : "A.A.Alekseev 1968",
                                  "A.A.Konstant inovsky,1969" : "A.A.Konstantinovsky,1969",
                                  "A.A.Malyshev 7 1960" : "A.A.Malyshev,1960",
                                  "A.A.Malyshev 9 l960" : "A.A.Malyshev,1960",
                                  "A.A.Mat lashov,1969" : "A.A.Matlashov,1969",
                                  "A.A.Matlashev,1969" : "A.A.Matlashov,1969",
                                  "A.A.Matlashov11969" : "A.A.Matlashov,1969",
                                  "A.A.Strizhkova?l975" : "A.A.Strizhkova,1975",
                                  "A.A.Strizhkova?l975" : "A.A.Strizhkova,1975",
                                  "A.A.Strizhkova11975" : "A.A.Strizhkova,1975",
                                  "A.A.Syas'ko 9l969" : "A.A.Syas'ko,1969",
                                  "A.A.Zh i tetsky,1963" : "A.A.Zhitetsky,1963", 
                                  "A.AoMatlashov,1969" : "A.A.Matlashov,1969",
                                  "A.AoStrizhkova,1975" : "A.A.Strizhkova,1975",
                                  "A.D.Kanischev.1959" : "A.D.Kanischev,1959",                                  
                                  "A.D.Silinsky 9 l963" : "A.D.Silinsky,1963",
                                  "A.D.Silirisky,1963" : "A.D.Silinsky,1963",
                                  "A.F.Azars~,1966" : "A.F.Azars,1966",
                                  "A.F.Baranov91950" : "A.F.Baranov,1950",
                                  "A.F.Kur~uzkin,1968" : "A.F.Kurguzkin,1968",
                                  "A.F.Mi khaylov,1948" : "A.F.Mikhaylov,1948",
                                  "A.F.Zausaev.1969" : "A.F.Zausaev,1969", 
                                  "A.G.Losev 91959" : "A.G.Losev,1959",
                                  "A.G.Senotrusov71964" : "A.G.Senotrusov,1964",
                                  "A.I.Kyshtymov i l959" : "A.I.Kyshtymov,1959",                                  
                                  "A.I.Samusin 9l974" : "A.I.Samusin,1974",
                                  "A.I.Samusin'1974" : "A.I.Samusin,1974",
                                  "A.I.Samusin's coll.,1974" : "A.I.Samusin,1974", 
                                  "A.I.Shevtsov?1967" : "A.I.Shevtsov,1967",
                                  "A.I.Vishnevsky?l973" : "A.I.Vishnevsky,1973",
                                  "A.K.~avel'ev,1950" : "A.K.savel'ev,1950",
                                  "A.K.Izveko~,'968" : "A.K.Izvekov,1968", 
                                  "A.K.Izvekov?l968" : "A.K.Izvekov,1968",
                                  "A.M.Demin?l950" : "A.M.Demin,1950",
                                  "A.M.Demin11945" : "A.M.Demin,1945",                                  
                                  "A.M~Demin,1945" : "A.M.Demin,1945",
                                  "A.N.Serebryakov91966" : "A.N.Serebryakov,1966",
                                  "A.N.Shapotin 9 l975" : "A.N.Shapotin,1975", 
                                  "A.N.Yatsko11964" : "A.N.Yatsko,1964",
                                  "A.S.Bochkarev?l984" : "A.S.Bochkarev,l984",
                                  "A.S.Krasil~nikov,1951" : "A.S.Krasil'nikov,1951",
                                  "A.S.Monyakin 9 l954" : "A.S.Monyakin,1954", 
                                  "A.V.Andr ianov,1939" : "A.V.Andrianov,1939",
                                  "A.V.Andrianov?l939" : "A.V.Andrianov,1939",
                                  "A.V.Andrianov'1939" : "A.V.Andrianov,1939",                                  
                                  "A.V.Andrianov91939" : "A.V.Andrianov,1939",
                                  "A.V.Fedotov 9 1961" : "A.V.Fedotov,1961",
                                  "A.V.Ivano~,1966" : "A.V.Ivanov,1966",
                                  "A.V.Ol eynikov,1978" : "A.V.Oleynikov,1978",
                                  "A.V.Oleyn i kov,1972" : "A.V.Oleynikov,1972",
                                  "A.V.Oleynikov 9 1975" : "A.V.Oleynikov,1975",
                                  "A.V.Oleynikov?l972" : "A.V.Oleynikov,1972", 
                                  "A.V.Vnukov 9 l960" : "A.V.Vnukov,1960",
                                  "A.V.Vnukov'1960" : "A.V.Vnukov,1960",
                                  "A.Ya.Radzivill91965" : "A.Ya.Radzivill,1965",                                  
                                  "A~M.Schepkin,1954" : "A.M.Schepkin,1954",
                                  "A~M.Strelov,1958" : "A.M.Strelov,1958",
                                  "Ao0.Kanischev,196l" : "A.O.Kanischev,1961", 
                                  "AoA.Mikhalevich,1969" : "A.A.Mikhalevich,1969",
                                  "AoFoMikhaylov,1948" : "A.F.Mikhaylov,1948",
                                  "AoM.Timofeev,1956" : "A.M.Timofeev,1956",
                                  "AoNoVishnevsky,1960" : "A.N.Vishnevsky,1960", 
                                  "AoP.Osipov,1964" : "A.P.Osipov,1964",
                                  "AoPoOsipov,1964" : "A.P.Osipov,1964",
                                  "B.D.Cheremis 9l966" : "B.D.Cheremis,1966",                                  
                                  "B.D.Trunov 9l963" : "B.D.Trunov,1963",
                                  "B.F.Rukavetz'1964" : "B.F.Rukavetz,1964",
                                  "B.G.Matveev 9 l964" : "B.G.Matveev,1964",
                                  "B.I.Akulov?l963" : "B.I.Akulov,1963",
                                  "B.I.Burde9l960" : "B.I.Burde,1960", 
                                  "B.L.Zalischak?l965" : "B.L.Zalischak,1965",
                                  "B.S.Nabrodov 9 1967" : "B.S.Nabrodov,1967",
                                  "B.Ya.Chernysh?l963" : "B.Ya.Chernysh,1963",                                  
                                  "D.A.Babushkin 91967" : "D.A.Babushkin,1967",
                                  "D.A.Babushkin?l967" : "D.A.Babushkin,1967",
                                  "D.I.Gusev 9 l961" : "D.I.Gusev,1961", 
                                  "D.I.Tro i tsky,1966" : "D.I.Troitsky,1966",
                                  "D.P.Vas'kovsky?l951" : "D.P.Vas'kovsky,1951",
                                  "D.S.Golota 7 1949" : "D.S.Golota,1949",
                                  "D.S.Golota 9 l953" : "D.S.Golota,1953", 
                                  "D.S.Golota?l949" : "D.S.Golota,1949",
                                  "E.~ .Izokh,1957" : "E.P.Izokh,1957",
                                  "E.A.Belyakov 91959" : "E.A.Belyakov,1959",                                  
                                  "E.A.Erofeeva?1955" : "E.A.Erofeeva,1955",
                                  "E.A.M~karov,1975" : "E.A.Makarov,1975",                                  
                                  "E.A.Makarov?l975" : "E.A.Makarov,1975",
                                  "E.A.Zaykov.1963" : "E.A.Zaykov,1963",
                                  "E.B.Nevretd inov,1972" : "E.B.Nevretdinov,1972", 
                                  "E.E.Zel ensky,1974" : "E.E.Zelensky,1974",
                                  "E.E.Zelensky'1974" : "E.E.Zelensky,1974",
                                  "E.G.Bordyugov 91964" : "E.G.Bordyugov,1964",
                                  "E.G.Bordyugov91973" : "E.G.Bordyugov,1973", 
                                  "E.LZelensky,1974" : "E.E.Zelensky,1974",
                                  "E.M.Bagadaev,19~" : "E.M.Bagadaev,1969",
                                  "E.M.Fal'kin,1969" : "E.M.Falkin,1969",                                  
                                  "E.M.Leyfman,I967" : "E.M.Leyfman,1967",
                                  "E.N.Brusko91974" : "E.N.Brusko,1974",
                                  "E.N.Zel eny,1971" : "E.N.Zeleny,1971",
                                  "E.N.Zeleny'1971" : "E.N.Zeleny,1971",
                                  "E.P.I zokh,1957" : "E.P.Izokh,1957", 
                                  "E.P.Izokh 9l957" : "E.P.Izokh,1957",
                                  "E.P.Izokh?l957" : "E.P.Izokh,1957",
                                  "E.P.Izokh91964" : "E.P.Izokh,1964",                                  
                                  "E.R.Izokh,1957" : "E.P.Izokh,1957",
                                  "E.S.Sukhov11963" : "E.S.Sukhov,1963",
                                  "E.T.Bubnov 9 l964" : "E.T.Bubnov,1964", 
                                  "E.T.Bubnov?l965" : "E.T.Bubnov,1965",
                                  "E.T.Bubnov'1964" : "E.T.Bubnov,1964",
                                  "E.To8ubnov,1964" : "E.T.Bubnov,1964",
                                  "E.ToBubnov,1964" : "E.T.Bubnov,1964", 
                                  "E.V.Barab~shev,1959" : "E.V.Barabashev,1959",
                                  "E.V.Barabashev 9 1962" : "E.V.Barabashev,1962",
                                  "E.V.Barabashev 91962" : "E.V.Barabashev,1962",                                  
                                  "E.V.Mikhayl ov,1973" : "E.V.Mikhaylov,1973",
                                  "E.V.Mikhaylov 9l973" : "E.V.Mikhaylov,1973",                                  
                                  "EoP.Izokh,1955" : "E.P.Izokh,1955",
                                  "EoVoBarabashev,196l" : "E.V.Barabashev,1961",
                                  "F.A.Gol ovachev,1935" : "F.A.Golovachev,1935", 
                                  "F.F.Pavlov?l936" : "F.F.Pavlov,1936",
                                  "F.G.Fedch i n11975" : "F.G.Fedchin,1975",
                                  "F.G.Fedch in,1975" : "F.G.Fedchin,1975",
                                  "F.G.Fedchin?l975" : "F.G.Fedchin,1975", 
                                  "F.G.Fedchin91975" : "F.G.Fedchin,1975",
                                  "F.GoFedchin,1975" : "F.G.Fedchin,1975",
                                  "F.I.Rostovsky?l965" : "F.I.Rostovsky,1965",                                  
                                  "F.P.Apel'tsin,1956" : "F.R.Apel'tsin,1956",
                                  "G,A.Valuy,1975" : "G.A.Valuy,1975",
                                  "G,I.Mikheev,1965" : "G.I.Mikheev,1965",
                                  "G.A oValuy,1975" : "G.A.Valuy,1975",
                                  "G.A.Grinberg'1965" : "G.A.Grinberg,1965", 
                                  "G.A.Val uy,1975" : "G.A.Valuy,1975",
                                  "G.A.Valuy 1975" : "G.A.Valuy,1975",
                                  "G.A.Valuy 9 1975" : "G.A.Valuy,1975",                                  
                                  "G.A.Valuy?l975" : "G.A.Valuy,1975",
                                  "G.A~Valuy,1975" : "G.A.Valuy,1975",
                                  "G.B.Gimmel'farb 9 l961" : "G.B.Gimmel'farb,1961", 
                                  "G.B.Gimmel'farb 9l961" : "G.B.Gimmel'farb;1961",
                                  "G.F.Zarzhitsky 7 1947" : "G.F.Zarzhitsky,1947",
                                  "G-.G.Kukhtinsky,1959" : "G.G.Kukhtinsky,1959",
                                  "G.G.Naumov 9 1978" : "G.G.Naumov,1978", 
                                  "G.G.Pezhemsky 9 1962" : "G.G.Pezhemsky,1962",
                                  "G.I.Bogomol ov'1965" : "G.I.Bogomolov'1965",
                                  "G.I.Mikheev 9 1971" : "G.I.Mikheev,1971",                                  
                                  "G.I.Mikheev?1964" : "G.I.Mikheev,1964",
                                  "G.I.Mikheev91965" : "G.I.Mikheev,1965",                                  
                                  "G.K.Kleschev?l958" : "G.K.Kleschev,1958",
                                  "G.L.Padal ka,1940" : "G.L.Padalka,1940",
                                  "G.L.Padal ka,1957" : "G.L.Padalka,1957", 
                                  "G.L.Padalka 9 1940" : "G.L.Padalka,1940",
                                  "G.L.Padalka 91940" : "G.L.Padalka,1940",
                                  "G.L.Padalka,194~" : "G.L.Padalka,1940",
                                  "G.l.Padalka,1940" : "G.L.Padalka,1940", 
                                  "G.L.Padalka?l940" : "G.L.Padalka,1940",
                                  "G.M.Litv inov,1963" : "G.M.Litvinov,1963",
                                  "G.M.Padalka,1957" : "G.L.Padalka,1957",                                  
                                  "G.M.Shapiro?l970" : "G.M.Shapiro,1970G.M.Shapiro,1970",
                                  "G.M.Shapiro91970" : "G.M.Shapiro,1970",
                                  "G.P.Antonov?l 975" : "G.P.Antonov,1975",
                                  "G.P.Preobrazhens~,1969" : "G.P.Preobrazhensky,1969",
                                  "G.S,Sonin,1976" : "G.S.Sonin,1976", 
                                  "G.S.Son i n,1976" : "G.S.Sonin,1976",
                                  "G.S.Sonin?l976" : "G.S.Sonin,1976",
                                  "G.S.Yaskelyainen 11967" : "G.S.Yaskelyainen,1967",                                  
                                  "G.V.Aleksandrov?l957" : "G.V.Aleksandrov,1957",
                                  "G.VoTafintsev 9 l963" : "G.V.Tafintsev,1963",
                                  "G~G.Naumov,1978" : "G.G.Naumov,1978", 
                                  "GoS oSonin,1976" : "G.S.Sonin,1976",
                                  "I oF.Grigor'ev,1957" : "I.F.Grigor'ev,1957",
                                  "I,F.Grigor'ev,1949" : "I.F.Grigor'ev,1949",
                                  "I.A.Gaev,1 960" : "I.A.Gaev,1960", 
                                  "I.A.Peresypkin 9 1972" : "I.A.Peresypkin,1972",
                                  "I.A.Sklyar?l938" : "I.A.Sklyar,1938",
                                  "I.A.Tombasov!l971" : "I.A.Tombasov,1971",                                  
                                  "I.E.Zaedinova?l957" : "I.E.Zaedinova,1957",
                                  "I.F.Grigor'ev?l941" : "I.F.Grigor'ev,1941",
                                  "I.FoGrigor'ev,1949" : "I.F.Grigor'ev,1949",
                                  "I.G.Vol kodav,1966" : "I.G.Volkodav,1966", 
                                  "I.G.Volkodav 9 l966" : "I.G.Volkodav,1966",
                                  "I.G.Volkodav 91967" : "I.G.Volkodav,1967",
                                  "I.G.Volkodav'1966" : "I.G.Volkodav,1966",                                  
                                  "I.I.Antushevich 7 l966" : "I.I.Antushevich,1966",
                                  "I.I.Antushevich 9 1966" : "I.I.Antushevich,1966",
                                  "I.I.Antushevich9 1966" : "I.I.Antushevich,1966", 
                                  "I.I.Kozyrevil968" : "I.I.Kozyrev,1968",
                                  "I.I.Puschin 91970" : "I.I.Puschin,1970",
                                  "I.M.Speranskaya,1 957" : "I.M.Speranskaya,1957", 
                                  "I.M.Speranskaya91962" : "I.M.Speranskaya,1962",
                                  "I.N.Fomin 9 1963" : "I.N.Fomin,1963",
                                  "I.N.Fomin?l961" : "I.N.Fomin,1961",                                  
                                  "I.P.Vasets ky,1965" : "I.P.Vasetsky,1965",
                                  "I.P.Vasetsky 9 1965" : "I.P.Vasetsky,1965",
                                  "I.P.Vasetsky?l965" : "I.P.Vasetsky,1965",
                                  "I.V.Mariich 91949" : "I.V.Mariich,1949", 
                                  "I.Z.Bur'yanova~l970" : "I.Z.Bur'yanova,1970",
                                  "I.Z.Bur'yarova,1968" : "I.Z.Bur'yanova,1968",
                                  "K.E,Rokin,1965" : "K.E.Rokin,1965",                                  
                                  "K.E.Rokin 9 1965" : "K.E.Rokin,1965",
                                  "K.E.Ronkin,1965" : "K.E.Rokin,1965",
                                  "K.F.Khat skevich,1968" : "K.F.Khatskevich,1968", 
                                  "K.F.Khatskevitz,1967" : "K.F.Khatskevich,1967",
                                  "K.K.Levashov?l964" : "K.K.Levashov,1964",
                                  "K.L.L'vov 9 1964" : "K.L.L'vov,1964",
                                  "K.L.L'vov 91964" : "K.L.L'vov,1964", 
                                  "K.L.L'vov 9l961" : "K.L.L'vov,1964",
                                  "K.N.Rud ich,1959" : "K.N.Rudich,1959",
                                  "K.P.Kara~anov,1962" : "K.P.Karavanov,1962",                                  
                                  "K.S.Sukhov 9 l963" : "K.S.Sukhov,1963",
                                  "K.V.Pl ast i nin,1966" : "K.V.Plastinin,1966",
                                  "K.V.Plast inin,1976" : "K.V.Plastinin,1976",
                                  "K.V.Plastinin 9 l976" : "K.V.Plastinin,1976", 
                                  "Kol.L'vov,1964" : "K.L.L'vov,1964",
                                  "L F.Sukhanova'1950" : "L.F.Sukhanova,1950",
                                  "L.A.Andrianov 91951" : "L.A.Andrianov,1951",                                  
                                  "L.A.Kozubova 9l966" : "L.A.Kozubova,1966",
                                  "L.A.Kozubovajl966" : "L.A.Kozubova,1966",
                                  "L.A.Mu sal i t in,1967" : "L.A.Musalitin,1967", 
                                  "L.A.Mu sal itin,1 967" : "L.A.Musalitin,1967",
                                  "L.A.Mu salitin,1967" : "L.A.Musalitin,1967",
                                  "L.A.Musal i tin,1967" : "L.A.Musalitin,1967",
                                  "L.A.Musal it i n,1967" : "L.A.Musalitin,1967", 
                                  "L.A.Musalit i n,1967" : "L.A.Musalitin,1967",
                                  "L.A.Musalit in,1967" : "L.A.Musalitin,1967",
                                  "L.A.Musalitin?l967" : "L.A.Musalitin,1967",                                  
                                  "l.A.Sidorchuk 7 1967" : "I.A.Sidorchuk,1967",
                                  "L.F.Dekhtereva?l964" : "L.F.Dekhtereva,1964",
                                  "L.G.Demin,I965" : "L.G.Demin,1965",
                                  "L.I.Agapova 9 l961" : "L.I.Agarova,1961", 
                                  "L.I.Sereda?l966" : "L.I.Sereda,1966",
                                  "L.L.Feoktistov,l968" : "L.L.Feoktistov,1968",
                                  "L.L.feoktistov?l968" : "L.L.Feoktistov,1968",                                  
                                  "L.L.Feoktistov?l968" : "L.L.Feoktistov,1968",
                                  "L.l.Sergeev,1967" : "L.I.Sergeev,1967",
                                  "L.l.Sergeev,1968" : "L.I.Sergeev,1968", 
                                  "L.l.Sergeev,1969" : "L.I.Sergeev,1969",
                                  "L.loSergeev,1967" : "L.I.Sergeev,1967",
                                  "l.M.Sargina 9 1960" : "I.M.Sargina,1960",
                                  "l.M.Sargina,1958" : "I.M.Sargina,1958", 
                                  "l.M.Speranskaya?l960" : "I.M.Speranskaya,1960",
                                  "l.N.Egorov,1970" : "I.N.Egorov,1970",
                                  "l.N.Fomin,1961" : "I.N.Fomin,1961",                                  
                                  "l.N.Zubrev,1952" : "I.N.Zubrev,1952",
                                  "L.P.Alaev.1962" : "L.P.Alaev,1962", 
                                  "L.P.Alaev91962" : "L.P.Alaev,1962",
                                  "l.P.Rachinskaya,1963" : "I.P.Rachinskaya,1963",
                                  "l.P.Vasets~,1965" : "I.P.Vasetsky,1965",
                                  "l.S.Valitskaya,1939" : "I.S.Valitskaya,1939", 
                                  "L.V olevlev,1964" : "L.V.Ievlev,1964",
                                  "L.V.Ievlev?l964" : "L.V.Ievlev,1964",
                                  "L.V.Ievlev~l964" : "L.V.Ievlev,1964",                                  
                                  "l.V.Zolotova,1954" : "I.V.Zolotova,1954",
                                  "l.Z.Bur'yanova,1968" : "I.Z.Bur'yanova,1968",
                                  "LoA.Kozubova,1964" : "L.A.Kozubova,1964",
                                  "loG.Volkodav,1967" : "I.G.Volkodav,1967", 
                                  "lololyakhov,1960" : "L.L.Lyakhov,1960",
                                  "LoloSereda,1966" : "L.l.Sereda,1966",
                                  "loN0Fomin'1961" : "I.N.Fomin,1961",                                  
                                  "LT.Bagadaev,1969" : "E.M.Bagadaev,1969",
                                  "M.A oFavorskaya,1961" : "M.A.Favorskaya,1961",
                                  "M.D.Berdn i kov,1965" : "M.D.Berdnikov,1965", 
                                  "M.D.Berdnikov 9 l965" : "M.D.Berdnikov,1965",
                                  "M.D.Berdnikov,I965" : "M.D.Berdnikov,1965",
                                  "M.D.Berdnikov?l965" : "M.D.Berdnikov,1965",
                                  "M.D.Berdnikov'1966" : "M.D.Berdnikov,1966", 
                                  "M.F.Dement'ev 91967" : "M.F.Dement'ev,1967",
                                  "M.G.Ravich 9l938" : "M.G.Ravich,1938",
                                  "M.G.Rub~l966" : "M.G.Rub,1966",                                  
                                  "M.I.Ni kul shin,1960" : "M.I.Nikul'shin,1960",
                                  "M.I.Nikul'shin 11959" : "M.I.Nikul'shin,1959", 
                                  "M.I.Nikul'shin 9 l960" : "M.I.Nikul'shin,1960",
                                  "M.I.Rabkin,194l" : "M.I.Rabkin,1941",
                                  "M.l.Novikova,1956" : "M.I.Novikova,1956",
                                  "M.N.Novikova?l956" : "M.N.Novikova.1956", 
                                  "M.P.Krutous,1360" : "M.P.Krutous,1960",
                                  "M.P.Materikov?1958" : "M.P.Materikov,1958",
                                  "M.S.Venchugo_ya,1937" : "M.S.Venchugova,1937",                                  
                                  "Mo0.Chasovitov 9 l959" : "M.O.Chasovitov,1959",
                                  "MoV oSukhin,1965" : "M.V.Sukhin,1965",
                                  "N oA.Urusov,1956" : "N.A.Urusov,1956",
                                  "N oP0Kostyakov'1966" : "N.P.Kostyakov,1966", 
                                  "N oPoKostyakov,1965" : "N.P.Kostyakov,1965",
                                  "N,I,Filatova,1968" : "N.I.Filatova,1968",
                                  "N.~styakov,1965" : "N.P.Kostyakov",                                  
                                  "N.A.Belyavsky,1951" : "N.A.Belyaevsky,1951",
                                  "N.A.Tseydl er,1969" : "N.A.Tseydler,1969",
                                  "N.A.Tseydler 9 l969" : "N.A.Tseydler,1969", 
                                  "N.E.Zavodskaya,1960" : "N.E.Zavadskaya,1960",
                                  "N.F.Smirnov?l963" : "N.F.Smirnov,1963",
                                  "N.G.Os i pov,1964" : "N.G.Osipov,1964",
                                  "N.I.F ilat ova,1968" : "N.I.Filatova,1968", 
                                  "N.I.Filatova?l968" : "N.I.Filatova,1968",
                                  "N.I.Shl epkin,1972" : "N.I.Shlepkin,1972",
                                  "N.I.Shl epkin,1976" : "N.I.Shlepkin,1976",                                  
                                  "N.I.Shlepkin?l972" : "N.I.Shlepkin,1972",
                                  "N.I.Tikhomirov?l964" : "N.I.Tikhomirov,1964", 
                                  "N.K.Dmitrochenko 9l965" : "N.K.Dmitrochenko,1965",
                                  "N.K.Dmitrochenko?l965" : "N.K.Dmitrochenko,1965",
                                  "N.K.Dmitrochenko~l965" : "N.K.Dmitrochenko,1965",
                                  "N.K.Dmitrochenko91968" : "N.K.Dmitrochenko,1968", 
                                  "N.K.Dmit rochenko,1964" : "N.K.Dmitrochenko,1964",
                                  "N.K.Flyaga?l962" : "N.K.Flyaga,1962",
                                  "N.K.Nikiforova 9 1973" : "N.K.Nikiforova,1973",                                  
                                  "N.K.Osipova 1955" : "N.K.Osipova,1955",
                                  "N.M.Keppen 9 1940" : "N.M.Keppen,1940",
                                  "N.M.Yanchuk9 l951" : "N.M.Yanchuk,1951",
                                  "N.M.Yanchuk91950" : "N.M.Yanchuk,1950", 
                                  "N.M.Zlobi n,1941" : "N.M.Zlobin,1941",
                                  "N.M.Zlobin?l941" : "N.M.Zlobin,1941",
                                  "N.N.Bindemann,1962" : "N.N.Bindermann,1962",                                  
                                  "N.N.Chaban91965" : "N.N.Chaban,1965",
                                  "N.N.Egorov?l970" : "N.N.Egorov,1970",
                                  "N.N.N~znamov,1967" : "N.N.Neznanov,1967", 
                                  "N.N.Neznanov,1 967" : "N.N.Neznanov,1967",
                                  "N.N.Tevashov,1966" : "N.N.Tevyashov,1966",
                                  "N.P oKostyakov,1966" : "N.P.Kostyakov,1966",
                                  "N.P.Ko styakov,1966" : "N.P.Kostyakov,1966", 
                                  "N.P.Kostikov,1968" : "N.P.Kostyakov,1968",
                                  "N.P.Kostyakov 9 1965" : "N.P.Kostyakov,1965",
                                  "N.V.Ichetovkin 9 l960" : "N.V.Ichetovkin,1960",                                  
                                  "N.V.Kuzhel eva,1969" : "N.V.Kuzheleva,1969",
                                  "N.V.Kuzheleva 9 1968" : "N.V.Kuzheleva,1968",
                                  "N.V.Kuzheleva 9 l968" : "N.V.Kuzheleva,1968", 
                                  "N.V.Kuzheleva9l968" : "N.V.Kuzheleva,1968",
                                  "N.V.Shtal' ,1958" : "N.V.Shtal',1958",
                                  "N.Vorob'ev's coll. ,1977" : "N.Vorob'ev's coll.,1977",                                  
                                  "N~I.Tikhomirov,1964" : "N.I.Tikhomirov,1964",
                                  "No!oTikhomirov,1964" : "N.I.Tikhomirov,1964",
                                  "NoloTikhomirov,1956" : "N.I.Tikhomirov,1956",
                                  "O.G.Epov 9 1972" : "O.G.Epov,1972", 
                                  "O.G.Starov?l970" : "O.G.Starov,1970",
                                  "O.G.Starov1977" : "O.G.Starov,1977",
                                  "O.K.Kalishevich's co~l." : "O.K.Kalishevich's coll.",                                  
                                  "O.K.Kalishevich's coll" : "O.K.Kalishevich's coll.",
                                  "O.N.Ivanov 9 1977" : "O.N.Ivanov,1977",
                                  "O.N.Ivanov'1972" : "O.N.Ivanov,1972", 
                                  "O.P.Razgonov?l960" : "O.P.Razgonov,1960",
                                  "O.V.Sosnitsky.1969" : "O.V.Sosnitsky,1969",
                                  "P.A.EpOV 9 l952" : "P.A.Epov,1952",
                                  "P.G.Verbitsky?l940" : "P.G.Verbitsky,1940", 
                                  "P.I.Kovaleva,1968" : "P.I.Kovalev,1968",
                                  "P.I.Taraban'ko?l960" : "P.I.Taraban'ko,1960",
                                  "P.M.Goloschukov 9 l963" : "P.M.Goloschukov,1963",                                  
                                  "P.M.Goloschukov11964" : "P.M.Goloschukov,1964",
                                  "P.M.Koshman,1960" : "P.N.Koshman,1960",
                                  "P.N.Sp i ridonov,1940" : "P.N.Spiridonov,1940", 
                                  "P.P.Ushakov 9 1940" : "P.P.Ushakov,1940",
                                  "PoPoSmol'sky,194l" : "P.P.Smol'sky,1941",
                                  "R.0.Galabala,1976" : "R.O.Galabala,1976",                                  
                                  "R.B,Umitbaev,1962" : "R.B.Umitbaev,1962",
                                  "R.B.Umitbaev 91962" : "R.B.Umitbaev,1962",
                                  "R.I.Ti tov,1959" : "R.N.Titov,1959",
                                  "R.N.Ti tov,1959" : "R.N.Titov,1959", 
                                  "R.O.Gal abala,1976" : "R.O.Galabala,1976",
                                  "R.O.Galabala?l976" : "R.O.Galabala,1976",
                                  "R.P.Pet rov,1945" : "R.P.Petrov,1945",                                  
                                  "R.V.Tsoy 9 l961" : "R.V.Tsoy,1961",
                                  "S,B.Kucherov,1939" : "S.B.Kucherov,1939",
                                  "S.A.Ivanov 9 1973" : "S.A.Ivanov,1973", 
                                  "S.A.Ivanov'1973" : "S.A.Ivanov,1973",
                                  "S.A.Korenbaum?l973" : "S.A.Korenbaum,1973",
                                  "S.A.Korenbaum~l973" : "S.A.Korenbaum,1973",
                                  "S.A.Korenbaum11973" : "S.A.Korenbaum,1973", 
                                  "S.B.Bravina'1955" : "S.B.Bravina,1955",
                                  "S.B.Kucherov 9l941" : "S.B.Kucherov,1941",
                                  "S.E.Sinits ky,1953" : "S.E.Sinitsky,1953",                                  
                                  "S.E.Sinitsky91953" : "S.E.Sinitsky,1953",
                                  "S.F,Lugov,1953" : "S.F.Lugov,1953",
                                  "S.F.Ermakov 9 l969" : "S.F.Ermakov,1969", 
                                  "S.F.Lugov91953" : "S.F.Lugov,1953",
                                  "S.G.Belobzhinsky's coll.9 1973" : "S.G.Belobzhinsky's coll.,1973",
                                  "S.G.Zhelin,1965" : "S.G.Zhelnina,1965",                                  
                                  "S.I.Fil at ov,1962" : "S.I.Filatov,1962",
                                  "S.I.Filatov 9 1962" : "S.I.Filatov,1962",
                                  "S.I.Gorokhovjl963" : "S.I.Gorokhov,1963",
                                  "S.I.P inaev,1975" : "S.I.Pinaev,1975", 
                                  "S.I.Pi naev,1975" : "S.I.Pinaev,1975",
                                  "S.I.Pinaev 9l975" : "S.I.Pinaev,1975",
                                  "S.l.Gorokhov,1949" : "S.I.Gorokhov,1949",                                  
                                  "S.l.Gorokhov,1962" : "S.I.Gorokhov,1962",
                                  "S.L.Shteynberg 7 1967" : "S.L.Shteynberg,1967",
                                  "S.M.Til'man 9 l956" : "S.M.Til'man,1956", 
                                  "S.P.Konoplev91938" : "S.P.Konoplev,1938",
                                  "S.P.Skuratovsky 9 1966" : "S.P.Skuratovsky,1966",
                                  "S.P.Smel ovsky,1968" : "S.P.Smelovsky,1968",
                                  "S.P.Smelovs~,1968" : "S.P.Smelovsky,1968", 
                                  "S.P.Smelovsky 91968" : "S.P.Smelovsky,1968",
                                  "S.P.Smelovsky,19668" : "S.P.Smelovsky,1968",
                                  "S.P.Smelovsky~l 968" : "S.P.Smelovsky,1968",                                  
                                  "S.P.Smelovsky'1968" : "S.P.Smelovsky,1968",
                                  "S.P.Smelovsky91971" : "S.P.Smelovsky,1971",
                                  "S.P.Stoyalov,1 961" : "S.P.Stoyalov,1961", 
                                  "S.P.Stoyanov,1961" : "S.P.Stoyalov,1961",
                                  "S.S.Lobunetz 9 1968" : "S.S.Lobunetz,1968",
                                  "S.V.Brav i na'1955" : "S.V.Bravina'1955",                                  
                                  "S.Z.Gorbachev 9 1966" : "S.Z.Gorbachev,1966",
                                  "SoF.Ermakov,1969" : "S.F.Ermakov,1969",
                                  "SoloPinaev,1975" : "S.I.Pinaev,1975",
                                  "V oK.Matushkin,1974" : "V.K.Matushkin,1974", 
                                  "V ol oStavitsky,1959" : "V.I.Stavitsky,1959",
                                  "V,A.Popeko,1968" : "V.A.Popeko,1968",
                                  "V,I.Sizykh,1968" : "V.I.Sizykh,1968",                                  
                                  "V,P.Krasnov,1969" : "V.P.Krasnov,1969",
                                  "V,S.Shmarlin,1968" : "V.S.Shmarlin,1968",
                                  "V,V.Shadynsky,1966" : "V.V.Shadynsky,1966", 
                                  "V.1.Fel'dman,1956" : "V.I.Fel'dman,1956",
                                  "V.A,Kaydalov,1976" : "V.A.Kaydalov,1976",
                                  "V.A,Popeko,1968" : "V.A.Popeko,1968",
                                  "V.A.~opeko,1967" : "V.A.Popeko,1967", 
                                  "V.A.Baskina?l965" : "V.A.Baskina,1965",
                                  "V.A.Faradz~ev,1971" : "V.A.Faradzhev,1971",
                                  "V.A.Faradzhev 9 1971" : "V.A.Faradzhev,1971",                                  
                                  "V.A.Faradzhev?l971" : "V.A.Faradzhev,1971",
                                  "V.A.Faradzhev9 l971" : "V.A.Faradzhev,1971",
                                  "V.A.Faradzhev91971" : "V.A.Faradzhev,1971", 
                                  "V.A.Grachevasl958" : "V.A.Grachev,1958",
                                  "V.A.Gulin 7 1960" : "V.A.Gulin,1960",
                                  "V.A.Gulin?l962" : "V.A.Gulin,1962",
                                  "V.A.Ivanov'1967" : "V.A.Ivanov,1967", 
                                  "V.A.Kamaletdinov~l971" : "V.A.Kamaletdinov,1971",
                                  "V.A.Kig~y,1955" : "V.A.Kigay,1955",
                                  "V.A.Lavr inovich,1966" : "V.A.Lavrinovich,1966",                                  
                                  "V.A.Lavri novich,1966" : "V.A.Lavrinovich,1966",
                                  "V.A.Popekd,1968" : "V.A.Popeko,1968",
                                  "V.A.Popeko 9 1968" : "V.A.Popeko,1968", 
                                  "V.A.Popeko 9 l967" : "V.A.Popeko,1967",
                                  "V.A.Popeko 91967" : "V.A.Popeko,1967",
                                  "V.A.Popeko,1 967" : "V.A.Popeko,1967",                                  
                                  "V.A.Popeko.1965" : "V.A.Popeko,1965",
                                  "V.A.Popeko.1967" : "V.A.Popeko,1967",
                                  "V.A.Popeko?l968" : "V.A.Popeko,1968",
                                  "V.A.Popeko~l967" : "V.A.Popeko,1967", 
                                  "V.A.Popeko91967" : "V.A.Popeko,1967",
                                  "V.A.Serebryakov,I959" : "V.A.Serebryakov,1959",
                                  "V.A.Serebryakov91958" : "V.A.Serebryakov,1958",                                  
                                  "V.A.Serebryakova,1959" : "V.A.Serebryakov,1959",
                                  "V.A.Sl ipchenko,1966" : "V.A.Slipchenko,1966",
                                  "V.A.Varl amov,1960" : "V.A.Varlamov,1960", 
                                  "V.A.Yarmolyuk?l956" : "V.A.Yarmolyuk,1956",
                                  "V.A.Zavaritsky91936" : "V.A.Zavaritsky,1936",
                                  "V.AoNovikov,1966" : "V.A.Novikov,1966",
                                  "V.E" : "V.E.Abel',1969", 
                                  "V.E.Abel' ,1969" : "V.E.Abel',1969",
                                  "V.E.Chepygin?l978" : "V.E.Chepygin,1978",
                                  "V.E.Skripnikov 7 1968" : "V.E.Skripnikov,1968",                                  
                                  "V.F.Karpichev.1960" : "V.F.Karpichev,1960",
                                  "V.F.Rukavetz,I964" : "V.F.Rukavetz,1964",
                                  "V.F.Znovik,1959" : "V.F.Zvonik,1959", 
                                  "V.G.Grigor'ev?l961" : "V.G.Grigor'ev,1961",
                                  "V.G.Korol'kov,19G9" : "V.G.Korol'kov,1969",
                                  "V.G.Korol'kov?l963" : "V.G.Korol'kov,1963",
                                  "V.G.Zhelt ovsky,1974" : "V.G.Zheltovsky,1974", 
                                  "V.G.Zheltovsky 9 l 973" : "V.G.Zheltovsky,1973",
                                  "V.G.Zheltovsky 9 l975" : "V.G.Zheltovsky,1975",
                                  "V.I.Fel'dman,I956" : "V.I.Fel'dman,1956",                                  
                                  "V.I.Kopytin,196l" : "V.I.Kopytin,1961",
                                  "V.I.Krasnokutsky11938" : "V.I.Krasnokutsky,1938",
                                  "V.I.Mus in,1970" : "V.I.Musin,1970", 
                                  "V.I.Na~zhny's coll.,1963" : "V.I.Naryzhny's coll.,1963",
                                  "V.I.Naryzhny's coll. ,1963" : "V.I.Naryzhny's coll.,1963",
                                  "V.I.Naryzhny's coll.,1 963" : "V.I.Naryzhny's coll.,1963",                                  
                                  "V.I.Naryzhny's coll.?1963" : "V.I.Naryzhny's coll.,1963",
                                  "V.I.Naryzhny's coll.9 1963" : "V.I.Naryzhny's coll.,1963",
                                  "V.I.Naryzhny's coll.91963" : "V.I.Naryzhny's coll.,1963",
                                  "V.I.Naryzhny's coll.j l963" : "V.I.Naryzhny's coll.,1963", 
                                  "V.I.Safronov, 1966" : "V.I.Safronov,1966",
                                  "V.I.Shavel' ,1967" : "V.I.Shavel',1967",
                                  "V.I.Shlepkin?l972" : "V.I.Shlepkin,1972",                                  
                                  "V.I.Sizykh 9 l964" : "V.I.Sizykh,1964",
                                  "V.I.Sizykh,1 964" : "V.I.Sizykh,1964",
                                  "V.I.Sizykh?l968" : "V.I.Sizykh,1968", 
                                  "V.I.T~tubalin,1967" : "V.I.Tutubalin,1967",
                                  "V.I-.Ushakov,1973" : "V.I.Ushakov,1973",
                                  "V.I~Safronov,1966" : "V.I.Safronov,1966",
                                  "V.K.Dorofeev 9l973" : "V.K.Dorofeev,1973", 
                                  "V.K.Dorofeev?1973" : "V.K.Dorofeev,1973",
                                  "V.K.Dorofeev?l971" : "V.K.Dorofeev,1971",
                                  "V.K.Matushkin?l972" : "V.K.Matushkin,1972",                                  
                                  "V.K.Matushkin?l974" : "V.K.Matushkin,1974",
                                  "V.K.Put intsev,1955" : "V.K.Putintsev,1955",
                                  "V.K.Sad~kov,1963" : "V.K.Sadakov,1963", 
                                  "V.K.Sadakov 9 l963" : "V.K.Sadakov,1963",
                                  "V.K.Sidakov,1963" : "V.K.Sadakov,1963",
                                  "V.KoDorofeev,1973" : "V.K.Dorofeev,1973",
                                  "V.l.Safronov?l966" : "V.I.Safronov,1966", 
                                  "V.loSafronov,1966" : "V.I.Safronov,1966",
                                  "V.loSizykh,1967" : "V.I.Sizykh,1967",
                                  "V.M.Kochkin 9 1966" : "V.M.Kochkin,1966",                                  
                                  "V.M.Koshkin,1966" : "V.M.Kochkin,1966",
                                  "V.M.Sergievsky,1965" : "V.M.Sergeevsky,1965",
                                  "V.M.Ushakov?l964" : "V.M.Ushakov,1964", 
                                  "V.N oStavitsky,1959" : "V.N.Stavitsky,1959",
                                  "V.N.Li patov,1960" : "V.N.Lipatov,1960",
                                  "V.N.lipatov,1958" : "V.N.Lipatov,1958",                                  
                                  "V.N.Mus i n,1970" : "V.N.Musin,1970",
                                  "V.N.Musin 11970" : "V.N.Musin,1970",
                                  "V.N.Musin 9 l970" : "V.N.Musin,1970",
                                  "V.N.Musin 91970" : "V.N.Musin,1970", 
                                  "V.N.Ovechkin?1978" : "V.N.Ovechkin,1978",
                                  "V.N.Stavit sky,1958" : "V.N.Stavitsky,1958",
                                  "V.N.Voevodin.1967" : "V.N.Voevodin,1967",                                  
                                  "V.N.Zavarit sky?l935" : "V.N.Zavaritsky,1935",
                                  "V.P oVasilenko,1966" : "V.P.Vasilenko,1966",
                                  "V.P.Krasnov 7 1958" : "V.P.Krasnov,1958", 
                                  "V.P.Krasnov?1968" : "V.P.Krasnov,1968",
                                  "V.P.Krasnov91966" : "V.P.Krasnov,1966",
                                  "V.P.Kuzne~sov,1960" : "V.P.Kuznetsov,1960",
                                  "V.P.Simanenko 9 1975" : "V.P.Simanenko,1975", 
                                  "V.P.Simonenko,1973" : "V.P.Simanenko,1973",
                                  "V.P.Simonenko,1977" : "V.P.Simanenko,1977",
                                  "V.S.Alkin91966" : "V.S.Alkin,1966",                                  
                                  "V.S.Bogoyavlensky 9 1964" : "V.S.Bogoyavlensky,1964",
                                  "V.S.Degtyarev,J964" : "V.S.Degtyarev,1964",                                  
                                  "V.S.Gmit ron" : "V.S.Gmitron",
                                  "V.S.lvanov,1968" : "V.S.Ivanov,1968",
                                  "V.S.lvanov,1971" : "V.S.Ivanov,1971", 
                                  "V.S.Shmarlin 9l968" : "V.S.Shmarlin,1968",
                                  "V.S.Smolich,~947" : "V.S.Smolich,1947",
                                  "V.V" : "V.V.Boyarshinov,1974",
                                  "V.V,Boyarshinov,1969" : "V.V.Boyarshinov,1969", 
                                  "V.V.Barabashev?1959" : "V.V.Barabashev,1959",
                                  "V.V.Boyarshiniv,1969" : "V.V.Boyarshinov,1969",
                                  "V.V.Boyarshinov?1974" : "V.V.Boyarshinov,1974",                                  
                                  "V.V.Boyarshinov?l959" : "V.V.Boyarshinov,1959",
                                  "V.V.Gol ozubov,1977" : "V.V.Golozubov,1977",
                                  "V.V.Gol'bert.1968" : "V.V.Gol'bert,1968", 
                                  "V.V.Gol'bert?l968" : "V.V.Gol'bert,1968",
                                  "V.V.Golozubov 91977" : "V.V.Golozubov,1977",
                                  "V.V.Sidorenko 9 1950" : "V.V.Sidorenko,1950",                                  
                                  "V.V.Sigov?l969" : "V.V.Sigov,1969",
                                  "V.V.Starchenko 11968" : "V.V.Starchenko,1968",
                                  "V.V.Starchenko 9 l961" : "V.V.Starchenko,1961",
                                  "V.V.Starchenko 9 l968" : "V.V.Starchenko,1968", 
                                  "V.V.Starchenko91967" : "V.V.Starchenko,1967",
                                  "V.V.Starchenko91968" : "V.V.Starchenko,1968",
                                  "V.V.Vetrennikov 91965" : "V.V.Vetrennikov,1965",                                  
                                  "V.VoStarchenko,1968" : "V.V.Starchenko,1968",
                                  "V.Ya.I l'chenko,1967" : "V.Ya.Ilchenko,1967",
                                  "V.Ya.Ilechko 9l960" : "V.Ya.Ilechko,1960", 
                                  "V~F.Alyavdin,1960" : "V.F.Alyavdin,1960",
                                  "V~V.Boyarshinov,1967" : "V.V.Boyarshinov,1967",
                                  "Vo!.Ushakov,1973" : "V.I.Ushakov,1973",
                                  "VoFoZubkov,1958" : "V.F.Zubkov,1958", 
                                  "VoG.Ditmar,1938" : "V.G.Ditmar,1938",
                                  "VoGoKravchenko,1975" : "V.G.Kravchenko,1975",
                                  "VoKoSadakov,1963" : "V.K.Sadakov,1963",                                  
                                  "Volchanskaya,I970" : "Volchanskaya,1970",
                                  "VoN.Voevodin,1967" : "V.N.Voevodin,1967",                                  
                                  "VoP.Kuznetsov,1960" : "V.P.Kuznetsov,1960",
                                  "VoV.Starchenko'1968" : "V.V.Starchenko,1968",
                                  "Y~.M.Vdovin,1958" : "Yu.M.Vdovin,1958", 
                                  "Yu oF.Gayko,1966" : "Yu.F.Gayko,1966",
                                  "Yu oNoSimonov,1964" : "Yu.N.Simonov,1964",
                                  "Yu.A.Bilibin91933" : "Yu.A.Bilibin,1933",
                                  "Yu.A.Borzakovsky91967" : "Yu.A.Borzakovsky,1967", 
                                  "Yu.D.Penyagin 9 1966" : "Yu.D.Penyagin,1966",
                                  "Yu.D.Penyagin 9 1968" : "Yu.D.Penyagin,1968",
                                  "Yu.D.Penyagin 91964" : "Yu.D.Penyagin,1964",                                  
                                  "Yu.D.Penyagin?l966" : "Yu.D.Penyagin,1966",
                                  "Yu.D.Penyagin91967" : "Yu.D.Penyagin,1967",
                                  "Yu.DoPenyagin,1966" : "Yu.D.Penyagin,1966", 
                                  "Yu.E.Dort-Goltz91963" : "Yu.E.Dort-Gol'tz,1963",
                                  "Yu.F.Misnik?l964" : "Yu.F.Misnik,1964",
                                  "Yu.G.lvanov 9 1964" : "Yu.G.Ivanov,1964",                                  
                                  "Yu.I.Maksimenko,19~3" : "Yu.I.Maksimenko,1963",
                                  "Yu.I.Scherbina'1965" : "Yu.I.Scherbina,1965",
                                  "Yu.M.Dovgal' ,1962" : "Yu.M.Dovgal',1962",
                                  "Yu.M.Neklyudov'1971" : "Yu.M.Neklyudov,1971", 
                                  "Yu.N.Simonov.1964" : "Yu.N.Simonov,1964",
                                  "Yu.P.Misans 91956" : "Yu.P.Misans,1956",
                                  "Yu.P.Try an in,1969" : "Yu.P.Tryanin,1969",                                  
                                  "Yu.P.Tryanin 9l969" : "Yu.P.Tryanin,1969",
                                  "Yu.PoTryanin,1969" : "Yu.P.Tryanin,1969",
                                  "Yu.T.Gurul ev,1 964" : "Yu.T.Gurulev,1964", 
                                  "Yu.V.Kazitsin?l958" : "Yu.V.Kazitsyn,1958",
                                  "Yu.V.Kazitsyn?l958" : "Yu.V.Kazitsyn,1958",
                                  "Yu.V.Kazitsin,1958" : "Yu.V.Kazitsyn,1958",
                                  "Yu.V.Kazitsyn?l967" : "Yu.V.Kazitsyn,1967", 
                                  "YuoMoYastremsky,1965" : "Yu.M.Yastremsky,1965",
                                  "YuoO.Penyagin,1962" : "Yu.O.Penyagin,1962",
                                  "Z.G.Karaev,1950" : "Z.G.Karaeva,1950",                                  
                                  "Z.G~Karaeva,1967" : "Z.G.Karaeva,1967",
                                  "Z.V.Sidorenko,I952" : "Z.V.Sidorenko,1952",                                  
                                  "ZoG.Karaeva,1950" : "Z.G.Karaeva,1950",
                                  "1.1.Kozyrev,1968" : "I.I.Kozyrev,1968",
                                  "A,N,Shapotin,1975" : "A.N.Shapotin,1975",
                                  "A,N.Bronnikov,1964" : "A.N.Bronnikov,1964",
                                  "E.AoZaykov,1963" : "E.A.Zaykov,1963",
                                  "E.P.lzokh,1957" : "E.P.Izokh,1957",
                                  "E.V. Mikhaylov,1973" : "E.V.Mikhaylov,1973",
                                  "G.B.Gimmel'farb;1961" : "G.B.Gimmel'farb,1961",
                                  "G.M.Shapiro,1970G.M.Shapiro,1970" : "G.M.Shapiro,1970",
                                  "K" : "V.V.Zakandyrin,1949",
                                  "N.A.Ageev,I964" : "N.A.Ageev,1964",
                                  "Yu.E.Dort-Goltz,1963" : "Yu.E.Dort-Gol'tz,1963"}

# %%
Vist_samyear_df['sampler+year'] = Vist_samyear_df['sampler+year'].replace(classification_renaming_dict10)

# %%
Vist_samyear_df.loc[:, 'sampler+year']
Vist_samyear_df.iloc[:, 12].value_counts().to_excel("../_RESULTS/sampyear_counts_new.xlsx")
